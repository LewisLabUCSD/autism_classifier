# %%
import pandas as pd
import numpy as np

# %%
for i in range(1,126):
    print("nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out"+str(i)+"/ > /data/bokan/6_sample_score/classification_perm/out"+str(i)+"/log.txt &")
# Out:
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out1/ > /data/bokan/6_sample_score/classification_perm/out1/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out2/ > /data/bokan/6_sample_score/classification_perm/out2/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out3/ > /data/bokan/6_sample_score/classification_perm/out3/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out4/ > /data/bokan/6_sample_score/classification_perm/out4/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out5/ > /data/bokan/6_sample_score/classification_perm/out5/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out6/ > /data/bokan/6_sample_score/classification_perm/out6/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out7/ > /data/bokan/6_sample_score/classification_perm/out7/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out8/ > /data/bokan/6_sample_score/classification_perm/out8/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out9/ > /data/bokan/6_sample_score/classification_perm/out9/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out10/ > /data/bokan/6_sample_score/classification_perm/out10/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out11/ > /data/bokan/6_sample_score/classification_perm/out11/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out12/ > /data/bokan/6_sample_score/classification_perm/out12/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out13/ > /data/bokan/6_sample_score/classification_perm/out13/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out14/ > /data/bokan/6_sample_score/classification_perm/out14/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out15/ > /data/bokan/6_sample_score/classification_perm/out15/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out16/ > /data/bokan/6_sample_score/classification_perm/out16/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out17/ > /data/bokan/6_sample_score/classification_perm/out17/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out18/ > /data/bokan/6_sample_score/classification_perm/out18/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out19/ > /data/bokan/6_sample_score/classification_perm/out19/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out20/ > /data/bokan/6_sample_score/classification_perm/out20/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out21/ > /data/bokan/6_sample_score/classification_perm/out21/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out22/ > /data/bokan/6_sample_score/classification_perm/out22/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out23/ > /data/bokan/6_sample_score/classification_perm/out23/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out24/ > /data/bokan/6_sample_score/classification_perm/out24/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out25/ > /data/bokan/6_sample_score/classification_perm/out25/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out26/ > /data/bokan/6_sample_score/classification_perm/out26/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out27/ > /data/bokan/6_sample_score/classification_perm/out27/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out28/ > /data/bokan/6_sample_score/classification_perm/out28/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out29/ > /data/bokan/6_sample_score/classification_perm/out29/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out30/ > /data/bokan/6_sample_score/classification_perm/out30/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out31/ > /data/bokan/6_sample_score/classification_perm/out31/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out32/ > /data/bokan/6_sample_score/classification_perm/out32/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out33/ > /data/bokan/6_sample_score/classification_perm/out33/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out34/ > /data/bokan/6_sample_score/classification_perm/out34/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out35/ > /data/bokan/6_sample_score/classification_perm/out35/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out36/ > /data/bokan/6_sample_score/classification_perm/out36/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out37/ > /data/bokan/6_sample_score/classification_perm/out37/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out38/ > /data/bokan/6_sample_score/classification_perm/out38/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out39/ > /data/bokan/6_sample_score/classification_perm/out39/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out40/ > /data/bokan/6_sample_score/classification_perm/out40/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out41/ > /data/bokan/6_sample_score/classification_perm/out41/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out42/ > /data/bokan/6_sample_score/classification_perm/out42/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out43/ > /data/bokan/6_sample_score/classification_perm/out43/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out44/ > /data/bokan/6_sample_score/classification_perm/out44/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out45/ > /data/bokan/6_sample_score/classification_perm/out45/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out46/ > /data/bokan/6_sample_score/classification_perm/out46/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out47/ > /data/bokan/6_sample_score/classification_perm/out47/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out48/ > /data/bokan/6_sample_score/classification_perm/out48/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out49/ > /data/bokan/6_sample_score/classification_perm/out49/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out50/ > /data/bokan/6_sample_score/classification_perm/out50/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out51/ > /data/bokan/6_sample_score/classification_perm/out51/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out52/ > /data/bokan/6_sample_score/classification_perm/out52/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out53/ > /data/bokan/6_sample_score/classification_perm/out53/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out54/ > /data/bokan/6_sample_score/classification_perm/out54/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out55/ > /data/bokan/6_sample_score/classification_perm/out55/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out56/ > /data/bokan/6_sample_score/classification_perm/out56/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out57/ > /data/bokan/6_sample_score/classification_perm/out57/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out58/ > /data/bokan/6_sample_score/classification_perm/out58/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out59/ > /data/bokan/6_sample_score/classification_perm/out59/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out60/ > /data/bokan/6_sample_score/classification_perm/out60/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out61/ > /data/bokan/6_sample_score/classification_perm/out61/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out62/ > /data/bokan/6_sample_score/classification_perm/out62/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out63/ > /data/bokan/6_sample_score/classification_perm/out63/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out64/ > /data/bokan/6_sample_score/classification_perm/out64/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out65/ > /data/bokan/6_sample_score/classification_perm/out65/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out66/ > /data/bokan/6_sample_score/classification_perm/out66/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out67/ > /data/bokan/6_sample_score/classification_perm/out67/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out68/ > /data/bokan/6_sample_score/classification_perm/out68/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out69/ > /data/bokan/6_sample_score/classification_perm/out69/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out70/ > /data/bokan/6_sample_score/classification_perm/out70/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out71/ > /data/bokan/6_sample_score/classification_perm/out71/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out72/ > /data/bokan/6_sample_score/classification_perm/out72/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out73/ > /data/bokan/6_sample_score/classification_perm/out73/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out74/ > /data/bokan/6_sample_score/classification_perm/out74/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out75/ > /data/bokan/6_sample_score/classification_perm/out75/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out76/ > /data/bokan/6_sample_score/classification_perm/out76/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out77/ > /data/bokan/6_sample_score/classification_perm/out77/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out78/ > /data/bokan/6_sample_score/classification_perm/out78/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out79/ > /data/bokan/6_sample_score/classification_perm/out79/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out80/ > /data/bokan/6_sample_score/classification_perm/out80/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out81/ > /data/bokan/6_sample_score/classification_perm/out81/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out82/ > /data/bokan/6_sample_score/classification_perm/out82/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out83/ > /data/bokan/6_sample_score/classification_perm/out83/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out84/ > /data/bokan/6_sample_score/classification_perm/out84/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out85/ > /data/bokan/6_sample_score/classification_perm/out85/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out86/ > /data/bokan/6_sample_score/classification_perm/out86/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out87/ > /data/bokan/6_sample_score/classification_perm/out87/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out88/ > /data/bokan/6_sample_score/classification_perm/out88/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out89/ > /data/bokan/6_sample_score/classification_perm/out89/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out90/ > /data/bokan/6_sample_score/classification_perm/out90/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out91/ > /data/bokan/6_sample_score/classification_perm/out91/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out92/ > /data/bokan/6_sample_score/classification_perm/out92/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out93/ > /data/bokan/6_sample_score/classification_perm/out93/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out94/ > /data/bokan/6_sample_score/classification_perm/out94/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out95/ > /data/bokan/6_sample_score/classification_perm/out95/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out96/ > /data/bokan/6_sample_score/classification_perm/out96/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out97/ > /data/bokan/6_sample_score/classification_perm/out97/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out98/ > /data/bokan/6_sample_score/classification_perm/out98/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out99/ > /data/bokan/6_sample_score/classification_perm/out99/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out100/ > /data/bokan/6_sample_score/classification_perm/out100/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out101/ > /data/bokan/6_sample_score/classification_perm/out101/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out102/ > /data/bokan/6_sample_score/classification_perm/out102/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out103/ > /data/bokan/6_sample_score/classification_perm/out103/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out104/ > /data/bokan/6_sample_score/classification_perm/out104/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out105/ > /data/bokan/6_sample_score/classification_perm/out105/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out106/ > /data/bokan/6_sample_score/classification_perm/out106/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out107/ > /data/bokan/6_sample_score/classification_perm/out107/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out108/ > /data/bokan/6_sample_score/classification_perm/out108/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out109/ > /data/bokan/6_sample_score/classification_perm/out109/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out110/ > /data/bokan/6_sample_score/classification_perm/out110/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out111/ > /data/bokan/6_sample_score/classification_perm/out111/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out112/ > /data/bokan/6_sample_score/classification_perm/out112/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out113/ > /data/bokan/6_sample_score/classification_perm/out113/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out114/ > /data/bokan/6_sample_score/classification_perm/out114/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out115/ > /data/bokan/6_sample_score/classification_perm/out115/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out116/ > /data/bokan/6_sample_score/classification_perm/out116/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out117/ > /data/bokan/6_sample_score/classification_perm/out117/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out118/ > /data/bokan/6_sample_score/classification_perm/out118/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out119/ > /data/bokan/6_sample_score/classification_perm/out119/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out120/ > /data/bokan/6_sample_score/classification_perm/out120/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out121/ > /data/bokan/6_sample_score/classification_perm/out121/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out122/ > /data/bokan/6_sample_score/classification_perm/out122/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out123/ > /data/bokan/6_sample_score/classification_perm/out123/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out124/ > /data/bokan/6_sample_score/classification_perm/out124/log.txt &
# nohup Rscript myFoldRunnerFn.R /data/bokan/6_sample_score/classification_perm/out125/ > /data/bokan/6_sample_score/classification_perm/out125/log.txt &

# %%
import json
import matplotlib.pyplot as plt

# %%
with open('/Volumes/Work/Vahid_work/classification_newcode_data/final_classificationSet_main/feature.json') as f:
    data = json.load(f)

# %%
# _the_table = pd.read_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_classificationSet_main/roc_mean.csv', index_col=0)
_the_table = pd.read_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_classificationSet_main/roc_mean1.csv', index_col=0)

# _the_table = _the_table.drop('sqda',axis=1)

# %%
_the_table_counts = pd.read_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_classificationSet_main/roc_counts.csv', index_col=0)
_the_table_counts = _the_table_counts.drop('sqda',axis=1)

# %%
_the_table_counts = _the_table_counts[(_the_table_counts == 5).all(1)]
_the_table = _the_table[_the_table.index.isin(_the_table_counts.index)]
# _the_table_counts

# %%
_the_table
# Out:
#                                                          reg    logReg  \
# real_no_no_sis                                      0.729458  0.704065
# real_no_grn4_sis                                    0.727629  0.700126
# real_no_grn4Cntl_sis                                0.743068  0.748503
# real_no_grn5_sis                                    0.735457  0.734369
# real_no_grn5Cntl_sis                                0.783854  0.769311
# ...                                                      ...       ...
# real_varImportance_selectVnotComFair_cor_no         0.820599  0.784916
# real_varImportance_selectVnotComFair_cor_pcr        0.803943  0.796634
# real_varImportance_selectVnotComFair_cor_plsr       0.820738  0.820678
# real_varImportance_selectVnotComFair_cor_cppls      0.820738  0.820678
# real_varImportance_selectVnotComFair_cor_zscore_no  0.763276  0.757741
#
#                                                          lda       qda  \
# real_no_no_sis                                      0.730116  0.626075
# real_no_grn4_sis                                    0.728958  0.695198
# real_no_grn4Cntl_sis                                0.743739  0.719365
# real_no_grn5_sis                                    0.736518  0.709036
# real_no_grn5Cntl_sis                                0.785565  0.777177
# ...                                                      ...       ...
# real_varImportance_selectVnotComFair_cor_no         0.821915  0.621278
# real_varImportance_selectVnotComFair_cor_pcr        0.803954  0.783101
# real_varImportance_selectVnotComFair_cor_plsr       0.822054  0.806013
# real_varImportance_selectVnotComFair_cor_cppls      0.822054  0.806013
# real_varImportance_selectVnotComFair_cor_zscore_no  0.762616  0.727772
#
#                                                     ridgeReg  lassoReg  \
# real_no_no_sis                                      0.727494  0.732941
# real_no_grn4_sis                                    0.723704  0.727101
# real_no_grn4Cntl_sis                                0.743616  0.742716
# real_no_grn5_sis                                    0.743648  0.735780
# real_no_grn5Cntl_sis                                0.780837  0.784549
# ...                                                      ...       ...
# real_varImportance_selectVnotComFair_cor_no         0.825353  0.839194
# real_varImportance_selectVnotComFair_cor_pcr        0.806672  0.803943
# real_varImportance_selectVnotComFair_cor_plsr       0.829042  0.820738
# real_varImportance_selectVnotComFair_cor_cppls      0.825643  0.820738
# real_varImportance_selectVnotComFair_cor_zscore_no  0.761695  0.762574
#
#                                                     ridgeLogReg  lassoLogReg  \
# real_no_no_sis                                         0.708650     0.704655
# real_no_grn4_sis                                       0.693255     0.697370
# real_no_grn4Cntl_sis                                   0.745010     0.747802
# real_no_grn5_sis                                       0.738512     0.733738
# real_no_grn5Cntl_sis                                   0.770660     0.771374
# ...                                                         ...          ...
# real_varImportance_selectVnotComFair_cor_no            0.826009     0.832184
# real_varImportance_selectVnotComFair_cor_pcr           0.806683     0.805343
# real_varImportance_selectVnotComFair_cor_plsr          0.827587     0.822054
# real_varImportance_selectVnotComFair_cor_cppls         0.831067     0.822054
# real_varImportance_selectVnotComFair_cor_zscore_no     0.758989     0.756381
#
#                                                     elasticNetLogReg  \
# real_no_no_sis                                              0.708643
# real_no_grn4_sis                                            0.695295
# real_no_grn4Cntl_sis                                        0.745668
# real_no_grn5_sis                                            0.737825
# real_no_grn5Cntl_sis                                        0.769263
# ...                                                              ...
# real_varImportance_selectVnotComFair_cor_no                 0.826637
# real_varImportance_selectVnotComFair_cor_pcr                0.806683
# real_varImportance_selectVnotComFair_cor_plsr               0.829034
# real_varImportance_selectVnotComFair_cor_cppls              0.827629
# real_varImportance_selectVnotComFair_cor_zscore_no          0.762412
#
#                                                     randomForest  boosting  \
# real_no_no_sis                                          0.692567  0.682705
# real_no_grn4_sis                                        0.718783  0.729441
# real_no_grn4Cntl_sis                                    0.713480  0.747901
# real_no_grn5_sis                                        0.755118  0.741484
# real_no_grn5Cntl_sis                                    0.753803  0.727099
# ...                                                          ...       ...
# real_varImportance_selectVnotComFair_cor_no             0.774696  0.771922
# real_varImportance_selectVnotComFair_cor_pcr            0.755005  0.695935
# real_varImportance_selectVnotComFair_cor_plsr           0.809483  0.755851
# real_varImportance_selectVnotComFair_cor_cppls          0.808055  0.761172
# real_varImportance_selectVnotComFair_cor_zscore_no      0.731423  0.677688
#
#                                                      bagging
# real_no_no_sis                                      0.692965
# real_no_grn4_sis                                    0.707810
# real_no_grn4Cntl_sis                                0.709691
# real_no_grn5_sis                                    0.738809
# real_no_grn5Cntl_sis                                0.749114
# ...                                                      ...
# real_varImportance_selectVnotComFair_cor_no         0.773061
# real_varImportance_selectVnotComFair_cor_pcr        0.747407
# real_varImportance_selectVnotComFair_cor_plsr       0.803197
# real_varImportance_selectVnotComFair_cor_cppls      0.805535
# real_varImportance_selectVnotComFair_cor_zscore_no  0.726078
#
# [1320 rows x 12 columns]

# %%
feature_method_dict = {}
the_array = np.array(_the_table)
main_feature_classifier = [[],[]]
import numpy as np
for i in _the_table.index.tolist():
    _name = "_".join(i.split("_")[1:])
    for j in _the_table.columns.tolist():
        if _the_table_counts.loc[i,j] ==5:
            if _the_table.loc[i,j] > 0.8:
                if _name not in feature_method_dict.keys():
                    feature_method_dict[_name] = [j]
                else:
                    feature_method_dict[_name].append(j)
            main_feature_classifier[0].append("@".join([_name,j]))
            main_feature_classifier[1].append(_the_table.loc[i,j])

# %%
main_feature_list = list(feature_method_dict.keys())
len(main_feature_list)
# Out:
# 268

# %%
sum([len(feature_method_dict[i]) for i in feature_method_dict.keys()])
# Out:
# 1822

# %%
import os.path
from os import path

# %%
temp_dict = {}
missed = []
feature_distribution = []
all_other = []
for i in data:
    the_route = i['method'][0]
    if  the_route.find('cppls') != -1 or the_route.find('plsr') != -1 or the_route.find('pcr') != -1:
        name = "_".join(the_route.split('_')[2:])
        if path.exists('/Volumes/Work/Vahid_work/classification_newcode_data/main_feature/'+the_route+'.txt'):
            gene_vec = [gene.rstrip("\n") for gene in open('/Volumes/Work/Vahid_work/classification_newcode_data/main_feature/'+the_route+'.txt').readlines()]
            [int(i) for i in gene_vec]
            if name not in temp_dict.keys():
                temp_dict[name] = [gene_vec]
            else:
                temp_dict[name].append(gene_vec)
            feature_distribution.append(len(gene_vec))
        else:
            print("Not found", the_route)
            missed.append(the_route)
    else:
        name = "_".join(i['method'][0].split('_')[2:])
        if name not in temp_dict.keys():
            temp_dict[name] = [i['features']]
        else:
            temp_dict[name].append(i['features'])
        all_other.append(len(i['features']))

# %%
"aaa\n".rstrip("\n")
# Out:
# 'aaa'

# %%
plt.hist([i for i in feature_distribution if i<100])
plt.xlim([0,100])
# Out:
# (0.0, 100.0)

# %%
plt.hist([i for i in all_other if i<100])
plt.xlim([0,500])
# Out:
# (0.0, 500.0)

# %% [markdown]
# # for the test

# %%
_the_table_test = pd.read_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_testDataset_HT12_test/roc_mean.csv', index_col=0)

_the_table_test = _the_table_test.drop('sqda', axis=1)
test_feature_method_dict = {}               
route_list_test = []
test_feature_classifier = [[],[]]

for i in _the_table_test.index.tolist():
    _name = "_".join(i.split("_")[1:])
    for j in _the_table_test.columns.tolist():
        if _the_table_test.loc[i,j] > 0.75:
            if _name not in test_feature_method_dict.keys():
                test_feature_method_dict[_name] = [j]
            else:
                test_feature_method_dict[_name].append(j)
        test_feature_classifier[0].append("@".join([_name,j]))
        test_feature_classifier[1].append(_the_table_test.loc[i,j])
route_list_test = list(test_feature_method_dict.keys())

with open('/Volumes/Work/Vahid_work/classification_newcode_data/final_testDataset_HT12_test/feature.json') as f:
    data_test = json.load(f)
            
test_temp_dict = {}
missed = []
for i in data_test:
    the_route = i['method'][0]
    if  the_route.find('cppls') != -1 or the_route.find('plsr') != -1 or the_route.find('pcr') != -1:
        name = "_".join(the_route.split('_')[1:])
        if path.exists('/Volumes/Work/Vahid_work/classification_newcode_data/test_feature/'+the_route+'.txt'):
            gene_vec = [gene.rstrip("\n") for gene in open('/Volumes/Work/Vahid_work/classification_newcode_data/test_feature/'+the_route+'.txt').readlines()]
            [int(i) for i in gene_vec]
            if name not in test_temp_dict.keys():
                test_temp_dict[name] = [gene_vec]
            else:
                test_temp_dict[name].append(gene_vec)
        else:
            print("Not found", the_route)
            missed.append(the_route)
    else:
        name = "_".join(i['method'][0].split('_')[1:])
        if name not in test_temp_dict.keys():
            test_temp_dict[name] = [i['features']]
        else:
            test_temp_dict[name].append(i['features'])
        
the_overlap = sorted(list(set(main_feature_list).intersection(set(route_list_test))))
# len(the_overlap)
# Out:
# Not found independent_cov_grn1_cppls
# Not found independent_cov_grn1Cntl_cppls

# %%
test_feature_table = pd.DataFrame(data={"test_feature": test_feature_classifier[0], 'test_roc':test_feature_classifier[1]})
print(test_feature_table.shape)
main_feature_table = pd.DataFrame(data={"main_feature": main_feature_classifier[0], 'main_roc':main_feature_classifier[1]})
print(main_feature_table.shape)
main_feature_table = main_feature_table[main_feature_table.main_feature.isin(test_feature_table.test_feature)]
main_feature_table = main_feature_table.sort_values(by="main_feature").reset_index(drop=True)
print(main_feature_table.shape)
test_feature_table = test_feature_table[test_feature_table.test_feature.isin(main_feature_table.main_feature)]
test_feature_table = test_feature_table.sort_values(by="test_feature").reset_index(drop=True)
print(test_feature_table.shape)
merged_table = pd.concat([test_feature_table, main_feature_table], axis=1).dropna()
merged_table = merged_table[~(merged_table == 0).any(axis=1)]
# Out:
# (19224, 2)
# (15840, 2)
# (15732, 2)
# (15732, 2)

# %%
test_feature_table[test_feature_table.test_roc>0.75]
# Out:
#                               test_feature  test_roc
# 2      cov_grn1Cntl_cppls@elasticNetLogReg  0.812144
# 3           cov_grn1Cntl_cppls@lassoLogReg  0.807400
# 4              cov_grn1Cntl_cppls@lassoReg  0.796964
# 5                   cov_grn1Cntl_cppls@lda  0.796964
# 6                cov_grn1Cntl_cppls@logReg  0.814042
# ...                                    ...       ...
# 15723         var_zscore_wgcna@lassoLogReg  0.790323
# 15724            var_zscore_wgcna@lassoReg  0.771347
# 15725                 var_zscore_wgcna@lda  0.787476
# 15726              var_zscore_wgcna@logReg  0.798861
# 15729                 var_zscore_wgcna@reg  0.787476
#
# [7717 rows x 2 columns]

# %%
main_feature_table[main_feature_table.main_roc>0.8]
# Out:
#                                          main_feature  main_roc
# 614    cov_selectVcomExpHC_cor_cppls@elasticNetLogReg  0.811870
# 615         cov_selectVcomExpHC_cor_cppls@lassoLogReg  0.809518
# 616            cov_selectVcomExpHC_cor_cppls@lassoReg  0.807812
# 617                 cov_selectVcomExpHC_cor_cppls@lda  0.807472
# 618              cov_selectVcomExpHC_cor_cppls@logReg  0.816562
# ...                                               ...       ...
# 15666                     var_zscore_grn3_plsr@logReg  0.807433
# 15668               var_zscore_grn3_plsr@randomForest  0.810693
# 15669                        var_zscore_grn3_plsr@reg  0.804307
# 15670                var_zscore_grn3_plsr@ridgeLogReg  0.809457
# 15671                   var_zscore_grn3_plsr@ridgeReg  0.810130
#
# [1822 rows x 2 columns]

# %%
import seaborn as sns
sns.scatterplot(data=merged_table, x="test_roc", y="main_roc", s=10)
sns.kdeplot(data=merged_table[["test_roc", "main_roc"]])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.scatterplot(data=merged_table, x="test_roc", y="main_roc", s=10)
sns.kdeplot(data=merged_table[["test_roc", "main_roc"]])
plt.title("ROC")
plt.xlim([0.55,0.93])
plt.ylim([0.65,0.9])
plt.show()

# %%
merged_table_high = merged_table[(merged_table.main_roc>0.8) & (merged_table.test_roc>0.75)]
merged_table_high
# Out:
#                                          test_feature  test_roc  \
# 614    cov_selectVcomExpHC_cor_cppls@elasticNetLogReg  0.785579
# 615         cov_selectVcomExpHC_cor_cppls@lassoLogReg  0.781784
# 616            cov_selectVcomExpHC_cor_cppls@lassoReg  0.781784
# 617                 cov_selectVcomExpHC_cor_cppls@lda  0.781784
# 618              cov_selectVcomExpHC_cor_cppls@logReg  0.798861
# ...                                               ...       ...
# 15448               var_selectVnotComHC_plsr@lassoReg  0.774194
# 15449                    var_selectVnotComHC_plsr@lda  0.774194
# 15453                    var_selectVnotComHC_plsr@reg  0.774194
# 15454            var_selectVnotComHC_plsr@ridgeLogReg  0.774194
# 15455               var_selectVnotComHC_plsr@ridgeReg  0.772296
#
#                                          main_feature  main_roc
# 614    cov_selectVcomExpHC_cor_cppls@elasticNetLogReg  0.811870
# 615         cov_selectVcomExpHC_cor_cppls@lassoLogReg  0.809518
# 616            cov_selectVcomExpHC_cor_cppls@lassoReg  0.807812
# 617                 cov_selectVcomExpHC_cor_cppls@lda  0.807472
# 618              cov_selectVcomExpHC_cor_cppls@logReg  0.816562
# ...                                               ...       ...
# 15448               var_selectVnotComHC_plsr@lassoReg  0.802811
# 15449                    var_selectVnotComHC_plsr@lda  0.802460
# 15453                    var_selectVnotComHC_plsr@reg  0.802811
# 15454            var_selectVnotComHC_plsr@ridgeLogReg  0.808513
# 15455               var_selectVnotComHC_plsr@ridgeReg  0.802884
#
# [1075 rows x 4 columns]

# %%
overlapped_route = merged_table_high.main_feature.tolist()

# %%
overlapped_route_dict={}
model_count = {}
for i in overlapped_route:
    _route, _method = i.split('@')
    if _route not in overlapped_route_dict.keys():
        overlapped_route_dict[_route] = [_method]
        model_count[_route] = 1
    else:
        overlapped_route_dict[_route].append(_method)
        model_count[_route] += 1
        
overlapped_route_dict
counts_list = []
for i in model_count:
    counts_list.append(model_count[i])

# %%
len([i for i in  counts_list if i>=6])
# Out:
# 99

# %%
import seaborn as sns
plt.hist(counts_list)
plt.title("Models generated by 192 routes")
plt.xlabel('# of model from one route that have AUC>0.8 in training and AUC>0.75 in test')
plt.xlim([0,13])
# Out:
# (0.0, 13.0)

# %%
#
class gene_share:
    def __init__(self, method, list_test, list_training):
        """list_test is a 2-d lst;
        list_trainning is also a 2-d list
        """
        self.method=method
        self.test_gene = list_test[0]
        self.overlap_count_dict = {}
        for i in self.test_gene:
            self.overlap_count_dict[i] = 0
        self.training_gene_count = {}
        self.training_gene = list(chain.from_iterable(list_training))
        for i in self.training_gene:
            self.training_gene_count[i] = 0
        self.exist_iter = len(list_training)
        self.total_number = len(self.test_gene)
        
        self.gene_weight = 0
        self.count_exist()
        
    def count_exist(self):
        for i in self.training_gene:
            if i in self.test_gene:
                self.overlap_count_dict[i] += 1/self.exist_iter
            self.training_gene_count[i] += 1/self.exist_iter
#         return self.count_dict
        _temp_weight = 0
#         print(self.count_dict)
        for i in self.overlap_count_dict.keys():
#             print(self.count_dict[i])
            _temp_weight += self.overlap_count_dict[i]/self.total_number
        self.gene_weight = _temp_weight
        
    def overlapped_high(self):
        "overlap/overlap high"
        return len(self.get_overlapped_high_test_gene())/len(self.get_overlapped_test_gene())
        
    def overlapped_all(self):
        return len(list(self.overlap_count_dict.keys()))/len(list(self.training_gene_count.keys()))
    
    def get_count_dict(self):
        return self.overlap_count_dict
    
    def get_high_training_gene(self):
        """return gene that have 0.5 more in 5-fold cross validation"""
        return_lst = [i for i in self.training_gene_count.keys() if self.training_gene_count[i]>0.5]
        return return_lst
    
    def get_overlapped_all_test_gene(self):
        """return gene that have all in the overlapped"""
        return_lst = [i for i in self.overlap_count_dict.keys() if self.overlap_count_dict[i]>0.9]
        return return_lst
    
    def get_overlapped_high_test_gene(self):
        """return gene that have 4/5 more in the overlapped"""

        return_lst = [i for i in self.overlap_count_dict.keys() if self.overlap_count_dict[i]>0.7]
        return return_lst
    
    def get_overlapped_mid_test_gene(self):
        """return gene that have 3/5 more in the overlapped"""
        return_lst = [i for i in self.overlap_count_dict.keys() if self.overlap_count_dict[i]>0.5]
        return return_lst
    
    def get_overlapped_test_gene(self):
        return_lst = [i for i in self.overlap_count_dict.keys() if self.overlap_count_dict[i]>0]
        return return_lst
    def get_all_training_gene(self):
#         print(list(set(self.training_gene)))
        return list(set(self.training_gene))
    
    def get_all_test_gene(self):
        return list(set(self.test_gene))
    
    def get_gene_weight(self):
        return self.gene_weight
    
    def get_overlap_test_ratio(self):
        return len(self.get_overlapped_test_gene())/len(self.get_all_test_gene())

# %%
# %matplotlib inline

# %%
from itertools import chain
feature_list = []
classifier_used = []
overlapped_all_dict = {}
overlapped_high_dict = {}
overlapped_mid_dict = {}
overlapped_dict = {}
test_all_dict = {}
overlapped_route_dict_list = list(overlapped_route_dict.keys())
        
# print(count)
count = 0
for i in overlapped_route_dict_list:
    if i not in test_temp_dict.keys() or i not in temp_dict.keys():
        print(i)
        continue
#     if i.find('plsr') != -1 or i.find('pcr') != -1:
#         count += 1
#     elif i.find('cppls') != -1 :
#         continue
# #     print(i)
#     print(test_temp_dict[i])
    _temp = gene_share(i, test_temp_dict[i], temp_dict[i])
    feature_list.append(_temp.get_gene_weight())
#     print(_temp.get_gene_weight())
#     print(feature_index_dict_method[i])
#     print(_temp.get_count_dict())
#     print("Overlap high",_temp.overlapped_high())
#     print("Overlap all",  _temp.overlapped_all())
#     print("get_all_training_gene", len(_temp.get_all_training_gene()))
#     print("get_high_training_gene", len(_temp.get_high_training_gene()))
#     print("get_overlapped_test_gene", len(_temp.get_overlapped_test_gene()))
#     print("overlapped_high", _temp.overlapped_high())
#     print("get_all_test_gene", len(_temp.get_all_test_gene()))
#     print("overlap_over_test_ratio", _temp.get_overlap_test_ratio())
#     print("get_all_test_gene",len(_temp.get_all_test_gene()))
    overlapped_all_dict[i] = _temp.get_overlapped_all_test_gene()
    overlapped_high_dict[i] = _temp.get_overlapped_high_test_gene()
    overlapped_mid_dict[i] = _temp.get_overlapped_mid_test_gene()
    overlapped_dict[i] = _temp.get_overlapped_test_gene()
    test_all_dict[i] = _temp.get_all_test_gene()
    "169 702 186 386 386"

# %%
import matplotlib.pyplot as plt
plt.hist(feature_list)
# Out:
# (array([15., 13.,  0.,  2., 32., 54., 29., 25.,  7., 14.]),
#  array([0.05      , 0.13833333, 0.22666667, 0.315     , 0.40333333,
#         0.49166667, 0.58      , 0.66833333, 0.75666667, 0.845     ,
#         0.93333333]),
#  <a list of 10 Patch objects>)

# %%
overlapped_all_dict
# Out:
# {'cov_selectVcomExpHC_cor_cppls': ['220042',
#   '9638',
#   '8644',
#   '128553',
#   '3820',
#   '4306',
#   '7704',
#   '8111',
#   '5996',
#   '94120',
#   '163732',
#   '57118',
#   '9454',
#   '115004'],
#  'cov_selectVcomExpHC_cor_plsr': ['220042',
#   '9638',
#   '8644',
#   '128553',
#   '3820',
#   '4306',
#   '7704',
#   '8111',
#   '5996',
#   '94120',
#   '163732',
#   '57118',
#   '9454',
#   '115004'],
#  'cov_selectVcomExpHC_cor_zscore_pcr': ['163732', '8111', '57595'],
#  'cov_selectVcomExpHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '3959',
#   '128553',
#   '8660',
#   '2209',
#   '10004',
#   '8111',
#   '3755',
#   '643550',
#   '10048',
#   '23523',
#   '57595',
#   '3418',
#   '5996',
#   '10975',
#   '4306',
#   '23031',
#   '6890',
#   '56935',
#   '3820',
#   '23067',
#   '728744',
#   '118788',
#   '2947',
#   '11237',
#   '163732',
#   '2635',
#   '23135',
#   '83931',
#   '28985',
#   '162466',
#   '6601',
#   '389816',
#   '112495',
#   '359845',
#   '23492',
#   '10403',
#   '23396',
#   '57210',
#   '27242',
#   '64174',
#   '283871',
#   '54820',
#   '597',
#   '91662',
#   '90007',
#   '654121',
#   '64411',
#   '10797',
#   '55858',
#   '5293',
#   '125950',
#   '7341',
#   '5684',
#   '8408',
#   '3707',
#   '3251',
#   '87',
#   '983',
#   '5914',
#   '81788',
#   '56666',
#   '57666',
#   '8019',
#   '56905',
#   '1729',
#   '84440',
#   '6907',
#   '26119',
#   '10507',
#   '24142'],
#  'cov_selectVcomExpHC_grn3Cntl_cppls': [],
#  'cov_selectVcomExpHC_grn3Cntl_plsr': [],
#  'cov_selectVcomExpHC_grn3_cor_no': [],
#  'cov_selectVcomExpHC_grn3_no': [],
#  'cov_selectVcomExpHC_pcr': ['6668',
#   '10286',
#   '359845',
#   '10403',
#   '2643',
#   '829',
#   '10643',
#   '23396',
#   '3428',
#   '5479',
#   '952',
#   '10048',
#   '6907',
#   '64411',
#   '55837',
#   '1729',
#   '400652',
#   '7707',
#   '343477',
#   '23492',
#   '125950',
#   '280655',
#   '10507',
#   '9739',
#   '83879',
#   '10635',
#   '134957',
#   '28985',
#   '26030',
#   '983',
#   '5293',
#   '83666',
#   '4782',
#   '649214',
#   '8019',
#   '5914',
#   '87',
#   '84548',
#   '7094',
#   '2210',
#   '56905',
#   '115362',
#   '6890',
#   '118788',
#   '80790',
#   '10797',
#   '29888',
#   '6601',
#   '3707',
#   '654121',
#   '5989',
#   '474338',
#   '728833',
#   '5721',
#   '387934',
#   '23429',
#   '23135',
#   '11237',
#   '5684',
#   '90007',
#   '9447',
#   '644310',
#   '23604',
#   '55858',
#   '56935',
#   '8445',
#   '29126'],
#  'cov_selectVcomExpHC_plsr': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '3959',
#   '128553',
#   '8660',
#   '2209',
#   '10004',
#   '8111',
#   '3755',
#   '643550',
#   '10048',
#   '23523',
#   '57595',
#   '3418',
#   '5996',
#   '10975',
#   '4306',
#   '23031',
#   '343099',
#   '6890',
#   '56935',
#   '3820',
#   '23067',
#   '728744',
#   '118788',
#   '2947',
#   '11237',
#   '163732',
#   '2635',
#   '23135',
#   '83931',
#   '28985',
#   '162466',
#   '6601',
#   '389816',
#   '112495',
#   '359845',
#   '23492',
#   '10403',
#   '23396',
#   '57210',
#   '27242',
#   '64174',
#   '283871',
#   '54820',
#   '91662',
#   '90007',
#   '654121',
#   '64411',
#   '10797',
#   '55858',
#   '5293',
#   '125950',
#   '7341',
#   '5684',
#   '8408',
#   '3707',
#   '3251',
#   '87',
#   '983',
#   '5914',
#   '81788',
#   '56666',
#   '5989',
#   '57666',
#   '8019',
#   '56905',
#   '1729',
#   '84440',
#   '6907',
#   '26119',
#   '23060',
#   '10507',
#   '24142'],
#  'cov_selectVcomFair_cor_cppls': ['9638'],
#  'cov_selectVcomFair_cor_logisticFwd': ['9638', '220042'],
#  'cov_selectVcomFair_cor_no': ['220042', '9638'],
#  'cov_selectVcomFair_cor_pcr': ['9638', '220042'],
#  'cov_selectVcomFair_cor_plsr': ['9638'],
#  'cov_selectVcomFair_cor_sis': ['220042', '9638'],
#  'cov_selectVcomFair_cppls': ['9638', '23067'],
#  'cov_selectVcomFair_logisticFwd': ['9638', '220042'],
#  'cov_selectVcomFair_no': ['10643', '220042', '23067', '9638'],
#  'cov_selectVcomFair_plsr': ['9638', '23067'],
#  'cov_selectVcomFair_sis': ['10643', '220042', '23067', '9638'],
#  'cov_selectVcomHC_cor_zscore_pcr': ['10004', '163732', '57595', '9638'],
#  'cov_selectVcomHC_grn3Cntl_no': [],
#  'cov_selectVcomHC_grn3_cor_no': [],
#  'cov_selectVcomHC_pcr': ['10643',
#   '2643',
#   '5989',
#   '280655',
#   '10403',
#   '10286',
#   '952',
#   '3428',
#   '829',
#   '55837',
#   '359845',
#   '26030',
#   '23396',
#   '5293',
#   '7707',
#   '654121',
#   '387934',
#   '5479',
#   '8408',
#   '4782',
#   '64411',
#   '6907',
#   '1729',
#   '125950',
#   '10507',
#   '9739',
#   '343477',
#   '118788',
#   '28985',
#   '400652',
#   '10635',
#   '56935',
#   '115362',
#   '2210',
#   '84548',
#   '83879',
#   '10797',
#   '23492',
#   '3707',
#   '8019',
#   '649214',
#   '55858',
#   '6601',
#   '23135',
#   '5721',
#   '57210',
#   '87',
#   '474338',
#   '5684',
#   '6890',
#   '29888',
#   '83666',
#   '10048',
#   '90007',
#   '84440',
#   '29126',
#   '9447'],
#  'cov_selectVnotComExpHC_cor_cppls': ['220042',
#   '9638',
#   '8644',
#   '128553',
#   '3820',
#   '4306',
#   '2999',
#   '8111',
#   '7704',
#   '163732',
#   '57118',
#   '94120',
#   '9454',
#   '115004'],
#  'cov_selectVnotComExpHC_cor_plsr': ['220042',
#   '9638',
#   '8644',
#   '128553',
#   '3820',
#   '4306',
#   '2999',
#   '8111',
#   '7704',
#   '163732',
#   '57118',
#   '94120',
#   '9454',
#   '115004'],
#  'cov_selectVnotComExpHC_cor_zscore_pcr': ['163732',
#   '4306',
#   '8111',
#   '9638',
#   '57595'],
#  'cov_selectVnotComExpHC_cor_zscore_sis': ['220042', '9638'],
#  'cov_selectVnotComExpHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '3959',
#   '128553',
#   '8660',
#   '2209',
#   '8111',
#   '3755',
#   '10004',
#   '10048',
#   '643550',
#   '23523',
#   '57595',
#   '3418',
#   '5996',
#   '4306',
#   '23031',
#   '10975',
#   '6890',
#   '56935',
#   '23067',
#   '3820',
#   '728744',
#   '2947',
#   '118788',
#   '163732',
#   '11237',
#   '2635',
#   '23135',
#   '83931',
#   '441168',
#   '28985',
#   '162466',
#   '23492',
#   '6601',
#   '112495',
#   '389816',
#   '10403',
#   '57210',
#   '23396',
#   '359845',
#   '27242',
#   '23097',
#   '283871',
#   '54820',
#   '90007',
#   '91662',
#   '597',
#   '64411',
#   '5293',
#   '80833',
#   '10797',
#   '654121',
#   '5684',
#   '125950',
#   '55858',
#   '7341',
#   '87',
#   '10635',
#   '3613',
#   '983',
#   '3707',
#   '60489',
#   '8408',
#   '3251',
#   '5914',
#   '55262',
#   '2210',
#   '3428',
#   '81788',
#   '57666',
#   '8019',
#   '115362',
#   '56666',
#   '1729',
#   '83879',
#   '56905',
#   '84440',
#   '9447',
#   '2643',
#   '140691',
#   '29888'],
#  'cov_selectVnotComExpHC_plsr': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '3959',
#   '128553',
#   '8660',
#   '2209',
#   '8111',
#   '3755',
#   '10004',
#   '10048',
#   '643550',
#   '23523',
#   '57595',
#   '3418',
#   '5996',
#   '4306',
#   '23031',
#   '10975',
#   '6890',
#   '56935',
#   '23067',
#   '3820',
#   '728744',
#   '2947',
#   '118788',
#   '163732',
#   '11237',
#   '2635',
#   '23135',
#   '83931',
#   '28985',
#   '162466',
#   '23492',
#   '6601',
#   '112495',
#   '389816',
#   '10403',
#   '57210',
#   '23396',
#   '359845',
#   '27242',
#   '23097',
#   '64174',
#   '283871',
#   '54820',
#   '90007',
#   '91662',
#   '64411',
#   '5293',
#   '10797',
#   '654121',
#   '5684',
#   '125950',
#   '55858',
#   '7341',
#   '87',
#   '983',
#   '3707',
#   '60489',
#   '8408',
#   '3251',
#   '391257',
#   '5914',
#   '55262',
#   '81788',
#   '57666',
#   '8019',
#   '5989',
#   '56666',
#   '1729',
#   '56905',
#   '84440',
#   '6907',
#   '728833',
#   '29888',
#   '26119',
#   '23060',
#   '24142'],
#  'cov_selectVnotComFair_cor_cppls': ['9638', '220042'],
#  'cov_selectVnotComFair_cor_logisticFwd': ['9638', '220042'],
#  'cov_selectVnotComFair_cor_no': ['220042', '9638'],
#  'cov_selectVnotComFair_cor_pcr': ['220042', '9638'],
#  'cov_selectVnotComFair_cor_plsr': ['9638', '220042'],
#  'cov_selectVnotComFair_cor_sis': ['220042', '9638'],
#  'cov_selectVnotComFair_cppls': ['9638', '220042'],
#  'cov_selectVnotComFair_logisticFwd': ['9638'],
#  'cov_selectVnotComFair_no': ['10643', '220042', '9638'],
#  'cov_selectVnotComFair_pcr': ['220042', '9638'],
#  'cov_selectVnotComFair_plsr': ['9638', '220042'],
#  'cov_selectVnotComFair_sis': ['10643', '220042', '9638'],
#  'cov_selectVnotComHC_cor_cppls': ['220042',
#   '9638',
#   '8644',
#   '128553',
#   '3820',
#   '4306',
#   '8111',
#   '7704',
#   '5996',
#   '163732',
#   '9454',
#   '94120',
#   '57118',
#   '115004'],
#  'cov_selectVnotComHC_cor_plsr': ['220042',
#   '9638',
#   '8644',
#   '128553',
#   '3820',
#   '4306',
#   '8111',
#   '7704',
#   '5996',
#   '163732',
#   '9454',
#   '94120',
#   '57118',
#   '115004'],
#  'cov_selectVnotComHC_cor_zscore_pcr': ['163732',
#   '4306',
#   '57595',
#   '8111',
#   '9638'],
#  'cov_selectVnotComHC_cor_zscore_sis': ['220042', '9638'],
#  'cov_selectVnotComHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '3959',
#   '8660',
#   '128553',
#   '2209',
#   '23523',
#   '643550',
#   '10048',
#   '10004',
#   '8111',
#   '3755',
#   '3418',
#   '57595',
#   '4306',
#   '23031',
#   '6890',
#   '56935',
#   '728744',
#   '3820',
#   '23067',
#   '118788',
#   '11237',
#   '23135',
#   '2635',
#   '163732',
#   '2947',
#   '28985',
#   '83931',
#   '162466',
#   '6601',
#   '112495',
#   '359845',
#   '23492',
#   '10403',
#   '23396',
#   '64174',
#   '57210',
#   '389816',
#   '23097',
#   '283871',
#   '54820',
#   '90007',
#   '27242',
#   '654121',
#   '91662',
#   '55858',
#   '125950',
#   '64411',
#   '10797',
#   '7341',
#   '5293',
#   '5684',
#   '3707',
#   '8408',
#   '55262',
#   '60489',
#   '3251',
#   '56666',
#   '983',
#   '87',
#   '81788',
#   '391257',
#   '5989',
#   '8019',
#   '57666',
#   '1729',
#   '6907',
#   '84440',
#   '26119',
#   '24142'],
#  'cov_selectVnotComHC_plsr': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '3959',
#   '8660',
#   '128553',
#   '2209',
#   '23523',
#   '643550',
#   '10048',
#   '10004',
#   '8111',
#   '3755',
#   '3418',
#   '57595',
#   '4306',
#   '23031',
#   '6890',
#   '56935',
#   '728744',
#   '3820',
#   '23067',
#   '118788',
#   '11237',
#   '23135',
#   '2635',
#   '163732',
#   '2947',
#   '28985',
#   '83931',
#   '162466',
#   '6601',
#   '112495',
#   '359845',
#   '23492',
#   '10403',
#   '23396',
#   '64174',
#   '57210',
#   '389816',
#   '23097',
#   '283871',
#   '54820',
#   '90007',
#   '27242',
#   '654121',
#   '91662',
#   '55858',
#   '125950',
#   '64411',
#   '10797',
#   '7341',
#   '5293',
#   '5684',
#   '3707',
#   '8408',
#   '55262',
#   '60489',
#   '3251',
#   '56666',
#   '983',
#   '87',
#   '81788',
#   '391257',
#   '5989',
#   '8019',
#   '57666',
#   '1729',
#   '6907',
#   '84440',
#   '26119',
#   '24142'],
#  'cov_var_selectVcomExpHC_cor_cppls': ['9638',
#   '8644',
#   '5996',
#   '3820',
#   '57595',
#   '163732',
#   '7704',
#   '51099',
#   '57118',
#   '115004'],
#  'cov_var_selectVcomExpHC_cor_plsr': ['9638',
#   '8644',
#   '5996',
#   '3820',
#   '57595',
#   '163732',
#   '7704',
#   '51099',
#   '57118',
#   '115004'],
#  'cov_var_selectVcomExpHC_cor_zscore_no': ['163732',
#   '2947',
#   '57595',
#   '8644',
#   '9638'],
#  'cov_var_selectVcomExpHC_cor_zscore_pcr': ['8644', '9638', '163732', '57595'],
#  'cov_var_selectVcomExpHC_cppls': ['9638',
#   '10643',
#   '8644',
#   '3755',
#   '8660',
#   '57595',
#   '3959',
#   '5996',
#   '163732',
#   '2209',
#   '2947',
#   '3418',
#   '389816',
#   '23135',
#   '6890',
#   '56935',
#   '118788',
#   '441168',
#   '23523',
#   '3820',
#   '400652',
#   '728744',
#   '23031',
#   '11237',
#   '2635',
#   '23492',
#   '359845',
#   '23396',
#   '112495',
#   '10403',
#   '28985',
#   '83931',
#   '26505',
#   '7341',
#   '23097',
#   '162466',
#   '10797',
#   '54820',
#   '654121',
#   '125950',
#   '57210',
#   '64174',
#   '5684',
#   '5293',
#   '8408',
#   '64411',
#   '3707',
#   '5914',
#   '5989',
#   '87',
#   '8019',
#   '56905',
#   '1729',
#   '56666'],
#  'cov_var_selectVcomExpHC_plsr': ['9638',
#   '10643',
#   '8644',
#   '3755',
#   '8660',
#   '57595',
#   '3959',
#   '5996',
#   '163732',
#   '2209',
#   '2947',
#   '3418',
#   '389816',
#   '23135',
#   '6890',
#   '56935',
#   '118788',
#   '441168',
#   '23523',
#   '3820',
#   '400652',
#   '728744',
#   '23031',
#   '11237',
#   '2635',
#   '23492',
#   '359845',
#   '23396',
#   '112495',
#   '10403',
#   '28985',
#   '83931',
#   '26505',
#   '7341',
#   '23097',
#   '162466',
#   '10797',
#   '54820',
#   '654121',
#   '125950',
#   '57210',
#   '64174',
#   '5684',
#   '5293',
#   '8408',
#   '64411',
#   '3707',
#   '5914',
#   '5989',
#   '87',
#   '8019',
#   '56905',
#   '1729',
#   '56666'],
#  'cov_var_selectVcomFair_no': ['10643', '23492', '54820', '9638'],
#  'cov_var_selectVcomFair_sis': ['10643', '9638'],
#  'cov_var_selectVnotComExpHC_cor_cppls': ['9638',
#   '8644',
#   '5996',
#   '3820',
#   '57595',
#   '7704',
#   '51099',
#   '163732',
#   '57118',
#   '115004'],
#  'cov_var_selectVnotComExpHC_cor_plsr': ['9638',
#   '8644',
#   '5996',
#   '3820',
#   '57595',
#   '7704',
#   '51099',
#   '163732',
#   '57118',
#   '115004'],
#  'cov_var_selectVnotComExpHC_cppls': ['9638',
#   '10643',
#   '3959',
#   '8644',
#   '57595',
#   '5996',
#   '3755',
#   '400652',
#   '2209',
#   '6890',
#   '8660',
#   '56935',
#   '3418',
#   '728744',
#   '2947',
#   '7341',
#   '23523',
#   '163732',
#   '441168',
#   '23135',
#   '3820',
#   '389816',
#   '23492',
#   '8408',
#   '118788',
#   '56905',
#   '83931',
#   '11237',
#   '10403',
#   '359845',
#   '10797',
#   '23031',
#   '2635',
#   '162466',
#   '5914',
#   '28985',
#   '112495',
#   '54820',
#   '60489',
#   '26505',
#   '87',
#   '64411',
#   '5684',
#   '23396',
#   '1729',
#   '125950',
#   '5293',
#   '23097',
#   '654121',
#   '64174',
#   '57210',
#   '3707',
#   '3251',
#   '57666',
#   '8019',
#   '56666',
#   '5989'],
#  'cov_var_selectVnotComExpHC_plsr': ['9638',
#   '10643',
#   '8644',
#   '3959',
#   '57595',
#   '2209',
#   '3755',
#   '5996',
#   '400652',
#   '6890',
#   '56935',
#   '728744',
#   '8660',
#   '441168',
#   '7341',
#   '3820',
#   '3418',
#   '23523',
#   '2947',
#   '8408',
#   '56905',
#   '28985',
#   '162466',
#   '163732',
#   '389816',
#   '23492',
#   '83931',
#   '23135',
#   '118788',
#   '359845',
#   '23031',
#   '10797',
#   '10403',
#   '11237',
#   '54820',
#   '2635',
#   '5914',
#   '1729',
#   '60489',
#   '5293',
#   '112495',
#   '64174',
#   '87',
#   '654121',
#   '26505',
#   '64411',
#   '5684',
#   '23396',
#   '23097',
#   '125950',
#   '57210',
#   '57666',
#   '56666',
#   '8019'],
#  'cov_var_selectVnotComFair_cor_logisticFwd': [],
#  'cov_var_selectVnotComFair_cor_no': ['9638'],
#  'cov_var_selectVnotComFair_no': ['10643', '9638'],
#  'cov_var_selectVnotComFair_sis': ['10643', '9638'],
#  'cov_var_zscore_cor_cppls': ['10461',
#   '9638',
#   '1824',
#   '8644',
#   '5996',
#   '318',
#   '3613',
#   '5730',
#   '3820',
#   '57595',
#   '2947',
#   '2946',
#   '55924',
#   '7704',
#   '163732',
#   '1455',
#   '284',
#   '441168',
#   '57118',
#   '2026',
#   '55022',
#   '64207',
#   '54741',
#   '5729',
#   '3597',
#   '7439',
#   '1380',
#   '596',
#   '140803',
#   '10207',
#   '653080',
#   '3458'],
#  'cov_var_zscore_cor_plsr': ['10461',
#   '9638',
#   '1824',
#   '8644',
#   '5996',
#   '318',
#   '3613',
#   '5730',
#   '3820',
#   '57595',
#   '2947',
#   '2946',
#   '55924',
#   '7704',
#   '163732',
#   '1455',
#   '284',
#   '441168',
#   '57118',
#   '2026',
#   '55022',
#   '64207',
#   '54741',
#   '5729',
#   '3597',
#   '7439',
#   '1380',
#   '596',
#   '140803',
#   '10207',
#   '653080',
#   '3458'],
#  'cov_var_zscore_cppls': ['9638',
#   '10643',
#   '10461',
#   '8644',
#   '3755',
#   '57595',
#   '5996',
#   '3959',
#   '8660',
#   '283948',
#   '2947',
#   '163732',
#   '5730',
#   '1824',
#   '2999',
#   '2209',
#   '3418',
#   '728715',
#   '79651',
#   '286354',
#   '389816',
#   '318',
#   '266747',
#   '441168',
#   '23523',
#   '3820',
#   '23031',
#   '259197',
#   '6890',
#   '56935',
#   '118788',
#   '23135',
#   '55022',
#   '5888',
#   '54741',
#   '1455',
#   '11237',
#   '1675',
#   '728744',
#   '644799',
#   '10477',
#   '112495',
#   '400652',
#   '28985',
#   '1380',
#   '2635',
#   '6601',
#   '5578',
#   '10797',
#   '23396',
#   '162466',
#   '359845',
#   '51099',
#   '23492',
#   '2946',
#   '83931',
#   '10403',
#   '5684',
#   '54820',
#   '8408',
#   '57210',
#   '276',
#   '10023',
#   '4782',
#   '5863',
#   '648984',
#   '5293',
#   '64407',
#   '26505',
#   '60489',
#   '5330',
#   '1387',
#   '7341',
#   '23053',
#   '58476',
#   '23097',
#   '4650',
#   '79143',
#   '654121',
#   '3707',
#   '3251',
#   '9757',
#   '64411',
#   '9919',
#   '64108',
#   '10598',
#   '3838',
#   '983',
#   '80256',
#   '125950',
#   '326624',
#   '5989',
#   '11322',
#   '10247',
#   '5914',
#   '80833',
#   '87',
#   '92162',
#   '7090',
#   '91662',
#   '115207',
#   '84440',
#   '7450',
#   '29089',
#   '9612',
#   '3609',
#   '8019',
#   '81857',
#   '55113',
#   '147841',
#   '2171',
#   '8522',
#   '55967',
#   '7704',
#   '55048',
#   '7094',
#   '387934',
#   '114769',
#   '9134',
#   '23130',
#   '57666',
#   '23162',
#   '1729',
#   '890',
#   '22883',
#   '387103',
#   '29855',
#   '1164',
#   '55108',
#   '730994',
#   '652864',
#   '6907',
#   '7444',
#   '728833',
#   '5430',
#   '26255',
#   '26119',
#   '10346',
#   '3161',
#   '56905',
#   '10507',
#   '6709',
#   '219771',
#   '7462',
#   '1033',
#   '3428',
#   '699',
#   '2643',
#   '84658',
#   '343990',
#   '124599',
#   '56666',
#   '124460',
#   '83696',
#   '10908',
#   '9220',
#   '6446',
#   '22898',
#   '6397'],
#  'cov_var_zscore_plsr': ['9638',
#   '10643',
#   '10461',
#   '3959',
#   '8644',
#   '5996',
#   '286354',
#   '57595',
#   '2999',
#   '3755',
#   '5888',
#   '2209',
#   '266747',
#   '400652',
#   '8660',
#   '3418',
#   '283948',
#   '728715',
#   '56935',
#   '1824',
#   '5578',
#   '6890',
#   '5730',
#   '163732',
#   '2947',
#   '23523',
#   '728744',
#   '7341',
#   '276',
#   '644799',
#   '8408',
#   '441168',
#   '6601',
#   '2946',
#   '118788',
#   '1387',
#   '162466',
#   '1455',
#   '23135',
#   '79651',
#   '318',
#   '56905',
#   '3820',
#   '23492',
#   '55022',
#   '11237',
#   '23031',
#   '389816',
#   '83931',
#   '4938',
#   '1380',
#   '10797',
#   '3985',
#   '54741',
#   '259197',
#   '10023',
#   '4782',
#   '54820',
#   '64108',
#   '359845',
#   '10403',
#   '112495',
#   '147841',
#   '58476',
#   '9919',
#   '326624',
#   '5914',
#   '60489',
#   '3161',
#   '80833',
#   '387103',
#   '87',
#   '5293',
#   '115207',
#   '1675',
#   '26255',
#   '2171',
#   '114769',
#   '91662',
#   '51099',
#   '2210',
#   '983',
#   '10477',
#   '2635',
#   '64411',
#   '28985',
#   '23396',
#   '64407',
#   '125950',
#   '5684',
#   '654121',
#   '3609',
#   '7704',
#   '10247',
#   '26505',
#   '26270',
#   '5863',
#   '648984',
#   '11322',
#   '57210',
#   '55113',
#   '29089',
#   '3707',
#   '10598',
#   '83879',
#   '699',
#   '5330',
#   '1164',
#   '343990',
#   '114294',
#   '23053',
#   '7090',
#   '29855',
#   '5989',
#   '83696',
#   '57666',
#   '1033',
#   '1111',
#   '9757',
#   '3838',
#   '55048',
#   '890',
#   '80256',
#   '5430',
#   '23097',
#   '79143',
#   '3251',
#   '4650',
#   '6709',
#   '64174',
#   '79901',
#   '64386',
#   '1729',
#   '26119',
#   '7462',
#   '7450',
#   '5729',
#   '219771',
#   '22883',
#   '92162',
#   '23130',
#   '55108',
#   '8522',
#   '124460',
#   '8019',
#   '730994',
#   '55967',
#   '10908',
#   '81857',
#   '9612',
#   '3428',
#   '84440',
#   '10346',
#   '23162',
#   '7094',
#   '57118',
#   '728833',
#   '387934',
#   '6907',
#   '7444',
#   '6446',
#   '9134',
#   '22898'],
#  'cov_zscore_cor_cppls': ['10461',
#   '220042',
#   '9638',
#   '8644',
#   '7850',
#   '128553',
#   '387837',
#   '3820',
#   '1824',
#   '318',
#   '3613',
#   '5730',
#   '642749',
#   '54797',
#   '10975',
#   '343099',
#   '4090',
#   '163233',
#   '57595',
#   '4306',
#   '2947',
#   '5996',
#   '57118',
#   '7704',
#   '8111',
#   '7174',
#   '55049',
#   '84263',
#   '2946',
#   '80352',
#   '9898',
#   '63874',
#   '150094',
#   '441168',
#   '80183',
#   '54741',
#   '311',
#   '55924',
#   '3305',
#   '2189',
#   '284',
#   '90417',
#   '9454',
#   '9256',
#   '140803',
#   '27287',
#   '9903',
#   '79866',
#   '140707',
#   '7088',
#   '245936',
#   '7439',
#   '10219',
#   '596',
#   '80094',
#   '2206',
#   '81793',
#   '55752',
#   '64207',
#   '90378',
#   '55545',
#   '58528',
#   '27106',
#   '1380',
#   '653080',
#   '259197',
#   '400077',
#   '10783',
#   '3516',
#   '10221',
#   '10189',
#   '9080',
#   '1455',
#   '25953',
#   '65993',
#   '648526',
#   '23239',
#   '648638',
#   '55582',
#   '3458',
#   '9619'],
#  'cov_zscore_cor_pcr': ['80231',
#   '9903',
#   '23528',
#   '79798',
#   '3684',
#   '54762',
#   '79671',
#   '653401',
#   '5836',
#   '57118',
#   '3597',
#   '284',
#   '27106',
#   '2057',
#   '4205',
#   '3613',
#   '55959',
#   '3458',
#   '140707',
#   '259197',
#   '146223',
#   '311',
#   '255758',
#   '9898',
#   '23569',
#   '55924',
#   '140606',
#   '253827',
#   '25953',
#   '3305',
#   '84263',
#   '10189',
#   '10975',
#   '4306',
#   '214',
#   '81793',
#   '81502',
#   '58528',
#   '391257',
#   '126789',
#   '9454',
#   '27287',
#   '10609',
#   '653904',
#   '10783',
#   '54916',
#   '65993',
#   '57168',
#   '10039',
#   '51754',
#   '3820',
#   '7174',
#   '1380',
#   '79866',
#   '92840',
#   '9985',
#   '90378',
#   '714',
#   '10023',
#   '63874',
#   '7439'],
#  'cov_zscore_cor_plsr': ['10461',
#   '220042',
#   '9638',
#   '8644',
#   '7850',
#   '128553',
#   '387837',
#   '3820',
#   '1824',
#   '318',
#   '3613',
#   '5730',
#   '642749',
#   '54797',
#   '10975',
#   '343099',
#   '4090',
#   '163233',
#   '57595',
#   '4306',
#   '2947',
#   '5996',
#   '57118',
#   '7704',
#   '8111',
#   '7174',
#   '55049',
#   '84263',
#   '2946',
#   '80352',
#   '9898',
#   '63874',
#   '150094',
#   '441168',
#   '80183',
#   '54741',
#   '311',
#   '55924',
#   '3305',
#   '2189',
#   '284',
#   '90417',
#   '9454',
#   '9256',
#   '140803',
#   '27287',
#   '9903',
#   '79866',
#   '140707',
#   '7088',
#   '245936',
#   '7439',
#   '10219',
#   '596',
#   '80094',
#   '2206',
#   '81793',
#   '55752',
#   '64207',
#   '90378',
#   '55545',
#   '58528',
#   '27106',
#   '1380',
#   '653080',
#   '259197',
#   '400077',
#   '10783',
#   '3516',
#   '10221',
#   '10189',
#   '9080',
#   '1455',
#   '25953',
#   '65993',
#   '648526',
#   '23239',
#   '648638',
#   '55582',
#   '3458',
#   '9619'],
#  'cov_zscore_cppls': ['220042',
#   '9638',
#   '10461',
#   '8644',
#   '10643',
#   '84166',
#   '128553',
#   '10975',
#   '286354',
#   '2999',
#   '10004',
#   '10048',
#   '23523',
#   '3959',
#   '266747',
#   '387837',
#   '8660',
#   '5888',
#   '57595',
#   '3418',
#   '2209',
#   '3755',
#   '2932',
#   '5996',
#   '162466',
#   '56935',
#   '57168',
#   '4306',
#   '79651',
#   '644799',
#   '643550',
#   '1387',
#   '642749',
#   '5730',
#   '22858',
#   '343099',
#   '56833',
#   '8111',
#   '1824',
#   '388555',
#   '23031',
#   '283948',
#   '728715',
#   '163732',
#   '26043',
#   '6601',
#   '28985',
#   '441168',
#   '147807',
#   '10538',
#   '150094',
#   '2947',
#   '3820',
#   '163233',
#   '112495',
#   '7850',
#   '81788',
#   '6890',
#   '83931',
#   '1163',
#   '84919',
#   '387103',
#   '55904',
#   '118432',
#   '23053',
#   '728744',
#   '3985',
#   '11237',
#   '653157',
#   '9919',
#   '8408',
#   '55022',
#   '64374',
#   '283871',
#   '91662',
#   '2946',
#   '23135',
#   '983',
#   '4627',
#   '51315',
#   '10477',
#   '90007',
#   '54820',
#   '23731',
#   '359845',
#   '5330',
#   '2171',
#   '867',
#   '326624',
#   '28977',
#   '5863',
#   '2635',
#   '54797',
#   '597',
#   '4650',
#   '60685',
#   '147841',
#   '1523',
#   '23492',
#   '318',
#   '3161',
#   '5430',
#   '55752',
#   '55049',
#   '220929',
#   '64407',
#   '5293',
#   '27242',
#   '3251',
#   '58476',
#   '64395',
#   '10403',
#   '9757',
#   '5684',
#   '7341',
#   '4090',
#   '54509',
#   '23396',
#   '23060',
#   '23097',
#   '56905',
#   '3707',
#   '22883',
#   '389816',
#   '9612',
#   '54741',
#   '644310',
#   '10797',
#   '7094',
#   '3838',
#   '79143',
#   '400652',
#   '6573',
#   '84557',
#   '26255',
#   '57459',
#   '57666',
#   '55262',
#   '27161',
#   '3687',
#   '1164',
#   '64411',
#   '5989',
#   '643997',
#   '125950',
#   '283149',
#   '55113',
#   '57210',
#   '9766',
#   '55108',
#   '11322',
#   '9739',
#   '10635',
#   '729837',
#   '87',
#   '5253',
#   '1729',
#   '5914',
#   '51128',
#   '60489',
#   '8019',
#   '115992',
#   '80256',
#   '401505',
#   '6772',
#   '654121',
#   '29888',
#   '728833',
#   '23067',
#   '4122',
#   '10023',
#   '3609',
#   '51099',
#   '55967',
#   '81',
#   '2664',
#   '55010',
#   '124599',
#   '10247',
#   '10507',
#   '9454',
#   '92162',
#   '8522',
#   '6201',
#   '29855',
#   '10346',
#   '9021',
#   '7444',
#   '7090',
#   '648984',
#   '80833',
#   '3324',
#   '93129',
#   '55092',
#   '23428',
#   '27043',
#   '29922',
#   '54762',
#   '54849',
#   '84148',
#   '4938',
#   '9993',
#   '6907',
#   '4782',
#   '6709',
#   '3428',
#   '730994',
#   '55858',
#   '890',
#   '64174',
#   '1033',
#   '219285',
#   '9134',
#   '349236',
#   '124460',
#   '64108',
#   '1058',
#   '7704',
#   '63035',
#   '5729',
#   '140691',
#   '276',
#   '83696',
#   '81857',
#   '29126',
#   '378708',
#   '23162',
#   '152100',
#   '1815',
#   '647195',
#   '84440',
#   '391257',
#   '55048',
#   '114769',
#   '6609',
#   '1111',
#   '10908',
#   '645351',
#   '116447',
#   '2643',
#   '24142',
#   '9318',
#   '29089',
#   '699',
#   '94120',
#   '7462',
#   '11339',
#   '861',
#   '140710',
#   '23130',
#   '26052',
#   '26505',
#   '343990',
#   '57458',
#   '652864',
#   '9683',
#   '23368',
#   '22898',
#   '9220',
#   '84658',
#   '5984',
#   '79901',
#   '6668',
#   '219771',
#   '55789',
#   '642031',
#   '118932',
#   '8407',
#   '54962',
#   '56666',
#   '161882',
#   '28996',
#   '115004',
#   '9261',
#   '474338',
#   '57140',
#   '64386',
#   '80005',
#   '23351',
#   '6397',
#   '114294',
#   '652694',
#   '22924',
#   '83666',
#   '57118',
#   '11130',
#   '84548',
#   '26270',
#   '151636',
#   '6241',
#   '26228'],
#  'cov_zscore_pcr': ['952',
#   '400759',
#   '4938',
#   '6668',
#   '9232',
#   '9636',
#   '1523',
#   '151636',
#   '5479',
#   '91543',
#   '641455',
#   '3482',
#   '64108',
#   '493',
#   '10561',
#   '10964',
#   '5586',
#   '26255',
#   '387934',
#   '653157',
#   '396',
#   '3627',
#   '3161',
#   '115361',
#   '699',
#   '147804',
#   '80325',
#   '28985',
#   '57178',
#   '9246',
#   '4627',
#   '4173',
#   '54434',
#   '83666',
#   '3609',
#   '259266',
#   '115362',
#   '286354',
#   '94240',
#   '2210',
#   '343477',
#   '10403',
#   '27043',
#   '55165',
#   '7272',
#   '219285',
#   '23633',
#   '3428',
#   '7283',
#   '9920',
#   '28996',
#   '10346',
#   '10247',
#   '3632',
#   '4061',
#   '64151',
#   '5294',
#   '8436',
#   '4209',
#   '890',
#   '6416',
#   '57459',
#   '118932',
#   '9683',
#   '51203',
#   '8318',
#   '2932',
#   '23399',
#   '29855',
#   '79143',
#   '125950',
#   '710',
#   '652694',
#   '10644',
#   '1058',
#   '118813',
#   '597',
#   '26270',
#   '9133',
#   '2209',
#   '650321',
#   '7094',
#   '57140',
#   '386757',
#   '991',
#   '3959',
#   '9833',
#   '6907',
#   '23492',
#   '11339',
#   '23586',
#   '55862',
#   '55388',
#   '5742',
#   '23162',
#   '6890',
#   '916',
#   '1111',
#   '10286',
#   '728833',
#   '27351',
#   '8897',
#   '387103',
#   '8986',
#   '9787',
#   '55108',
#   '1163',
#   '55010',
#   '2643',
#   '5721',
#   '4495',
#   '23604',
#   '79621',
#   '91289',
#   '55215',
#   '79101',
#   '7298',
#   '8175',
#   '56905',
#   '64174',
#   '23303',
#   '6491',
#   '1601',
#   '647195',
#   '84658',
#   '85464',
#   '56666',
#   '57097',
#   '9381',
#   '6790',
#   '219771',
#   '9739',
#   '22883',
#   '55789',
#   '6614',
#   '9612',
#   '83879',
#   '404093',
#   '147807',
#   '29098',
#   '5427',
#   '9766',
#   '4217',
#   '891',
#   '2171',
#   '9220',
#   '23067',
#   '728973',
#   '10507',
#   '153222',
#   '134957',
#   '150468',
#   '440068',
#   '22898',
#   '29126',
#   '11065',
#   '6601',
#   '65125',
#   '80790',
#   '2033',
#   '642502',
#   '22974',
#   '51257',
#   '8445',
#   '983',
#   '359845',
#   '54625',
#   '4782',
#   '145815',
#   '867',
#   '829',
#   '9318',
#   '23396',
#   '26228',
#   '80256',
#   '7341',
#   '2057',
#   '6397',
#   '114769',
#   '57634',
#   '5914',
#   '26030',
#   '79019',
#   '9319',
#   '57172',
#   '648343',
#   '6241',
#   '10733',
#   '130773',
#   '644310',
#   '645351',
#   '9903',
#   '306',
#   '253980',
#   '54849',
#   '9447',
#   '4784',
#   '23580',
#   '83955',
#   '84300',
#   '51128',
#   '8407',
#   '5590',
#   '87',
#   '56255',
#   '7462',
#   '54552',
#   '23429',
#   '3429',
#   '27161',
#   '2664',
#   '3148',
#   '54509',
#   '654074',
#   '23468',
#   '5293',
#   '9134',
#   '83696',
#   '1033',
#   '84277',
#   '1820',
#   '283149',
#   '10643',
#   '117852',
#   '7707',
#   '644380',
#   '64411',
#   '115992',
#   '7444',
#   '56969',
#   '9898',
#   '91748',
#   '140710',
#   '10635',
#   '7469',
#   '23099',
#   '56935',
#   '11157',
#   '307',
#   '8019',
#   '222166',
#   '26191',
#   '10004',
#   '55661',
#   '81788',
#   '11262',
#   '84148',
#   '57419',
#   '9261',
#   '4208',
#   '1729',
#   '5253',
#   '401505',
#   '3838',
#   '4122',
#   '84548',
#   '11130',
#   '654121',
#   '55048',
#   '81620',
#   '163882',
#   '8408',
#   '6772',
#   '10313',
#   '29089',
#   '23135',
#   '644314',
#   '55810',
#   '4683',
#   '22905',
#   '10174',
#   '92162',
#   '221',
#   '55858',
#   '5330',
#   '55837',
#   '80005',
#   '651751',
#   '58472',
#   '83931',
#   '143543',
#   '3687',
#   '3707',
#   '84864',
#   '23097',
#   '5989',
#   '26505',
#   '10384',
#   '55113',
#   '2237',
#   '643550',
#   '23053',
#   '4331',
#   '84440',
#   '55312',
#   '29888',
#   '6609',
#   '9757',
#   '11004',
#   '23060',
#   '652864',
#   '8553',
#   '6404',
#   '5578',
#   '161882',
#   '4650',
#   '91937',
#   '115004',
#   '9993',
#   '2635',
#   '254048',
#   '3613',
#   '5684',
#   '343990',
#   '55262',
#   '1822',
#   '23351',
#   '643997',
#   '10908',
#   '23368',
#   '57210',
#   '81',
#   '81857',
#   '162466',
#   '11322',
#   '6573',
#   '124599',
#   '10048',
#   '7090',
#   '94120',
#   '60489',
#   '91662',
#   '114294',
#   '23223',
#   '400652',
#   '378708',
#   '51667',
#   '9919',
#   '23130',
#   '5430',
#   '55015',
#   '135114',
#   '25953',
#   '90007',
#   '10797',
#   '57458',
#   '63035',
#   '6487',
#   '651816',
#   '474338',
#   '54962',
#   '6446',
#   '1164'],
#  'cov_zscore_plsr': ['220042',
#   '9638',
#   '10461',
#   '8644',
#   '10643',
#   '84166',
#   '128553',
#   '10975',
#   '286354',
#   '2999',
#   '10004',
#   '10048',
#   '23523',
#   '3959',
#   '266747',
#   '387837',
#   '8660',
#   '5888',
#   '57595',
#   '3418',
#   '2209',
#   '3755',
#   '2932',
#   '5996',
#   '162466',
#   '56935',
#   '57168',
#   '4306',
#   '79651',
#   '644799',
#   '643550',
#   '1387',
#   '642749',
#   '5730',
#   '22858',
#   '343099',
#   '56833',
#   '8111',
#   '1824',
#   '388555',
#   '23031',
#   '283948',
#   '728715',
#   '163732',
#   '26043',
#   '6601',
#   '28985',
#   '441168',
#   '147807',
#   '10538',
#   '150094',
#   '4205',
#   '2947',
#   '3820',
#   '163233',
#   '112495',
#   '7850',
#   '81788',
#   '118788',
#   '6890',
#   '83931',
#   '1163',
#   '84919',
#   '387103',
#   '55904',
#   '112770',
#   '118432',
#   '23053',
#   '728744',
#   '3985',
#   '11237',
#   '653157',
#   '9919',
#   '79412',
#   '8408',
#   '5578',
#   '55022',
#   '64374',
#   '283871',
#   '91662',
#   '2946',
#   '23135',
#   '983',
#   '4627',
#   '51315',
#   '10477',
#   '90007',
#   '54820',
#   '23731',
#   '359845',
#   '5330',
#   '2171',
#   '23741',
#   '867',
#   '326624',
#   '28977',
#   '27351',
#   '5863',
#   '2635',
#   '54797',
#   '597',
#   '4650',
#   '60685',
#   '147841',
#   '1523',
#   '23492',
#   '318',
#   '3161',
#   '5430',
#   '55752',
#   '55049',
#   '64407',
#   '5293',
#   '27242',
#   '3251',
#   '58476',
#   '64395',
#   '10403',
#   '9757',
#   '5684',
#   '7341',
#   '54509',
#   '23396',
#   '23060',
#   '23097',
#   '56905',
#   '644655',
#   '3707',
#   '22883',
#   '389816',
#   '9612',
#   '54741',
#   '644310',
#   '10797',
#   '7094',
#   '3838',
#   '79143',
#   '400652',
#   '6573',
#   '84557',
#   '26255',
#   '57459',
#   '57666',
#   '55262',
#   '27161',
#   '3687',
#   '1164',
#   '64411',
#   '5989',
#   '643997',
#   '125950',
#   '283149',
#   '55113',
#   '57210',
#   '9766',
#   '55108',
#   '11322',
#   '9739',
#   '10635',
#   '87',
#   '5253',
#   '1729',
#   '5914',
#   '51128',
#   '60489',
#   '8019',
#   '115992',
#   '80256',
#   '401505',
#   '654121',
#   '29888',
#   '728833',
#   '23067',
#   '4122',
#   '10023',
#   '3609',
#   '55967',
#   '81',
#   '2664',
#   '55010',
#   '124599',
#   '10247',
#   '10507',
#   '9454',
#   '92162',
#   '8522',
#   '6201',
#   '29855',
#   '10346',
#   '9021',
#   '7444',
#   '7090',
#   '51203',
#   '648984',
#   '93129',
#   '55092',
#   '23428',
#   '27043',
#   '3613',
#   '29922',
#   '54849',
#   '84148',
#   '4938',
#   '9993',
#   '6907',
#   '80183',
#   '4782',
#   '6709',
#   '9256',
#   '3428',
#   '730994',
#   '55858',
#   '9232',
#   '890',
#   '64174',
#   '1033',
#   '9134',
#   '26119',
#   '349236',
#   '124460',
#   '64108',
#   '1058',
#   '7704',
#   '63035',
#   '140691',
#   '276',
#   '83696',
#   '81857',
#   '378708',
#   '23162',
#   '152100',
#   '1815',
#   '647195',
#   '84440',
#   '391257',
#   '3632',
#   '55048',
#   '221',
#   '54955',
#   '114769',
#   '6609',
#   '1111',
#   '10908',
#   '645351',
#   '116447',
#   '2643',
#   '24142',
#   '9318',
#   '29089',
#   '699',
#   '56255',
#   '94120',
#   '7462',
#   '11339',
#   '861',
#   '140710',
#   '23130',
#   '26052',
#   '26505',
#   '10598',
#   '343990',
#   '57458',
#   '652864',
#   '9683',
#   '23368',
#   '22898',
#   '9220',
#   '84658',
#   '5984',
#   '1822',
#   '23399',
#   '6668',
#   '219771',
#   '55789',
#   '642031',
#   '54962',
#   '56666',
#   '161882',
#   '28996',
#   '10733',
#   '9261',
#   '153222',
#   '55165',
#   '474338',
#   '57140',
#   '352954',
#   '64386',
#   '23351',
#   '6397',
#   '114294',
#   '22924',
#   '57118',
#   '84548',
#   '118813',
#   '54443',
#   '6491',
#   '6241',
#   '26228'],
#  'no_selectVcomExpHC_cor_cppls': ['9638',
#   '220042',
#   '5621',
#   '8644',
#   '122525',
#   '128553',
#   '55153',
#   '79673',
#   '23365',
#   '3820',
#   '57595',
#   '7010',
#   '4306',
#   '284367',
#   '23243',
#   '119504',
#   '10126',
#   '7704',
#   '22927',
#   '8111',
#   '83877',
#   '7428',
#   '22859',
#   '94120',
#   '283876',
#   '165631',
#   '57118',
#   '163732',
#   '79595',
#   '311',
#   '10505'],
#  'no_selectVcomExpHC_cor_plsr': ['9638',
#   '220042',
#   '5621',
#   '8644',
#   '122525',
#   '128553',
#   '55153',
#   '79673',
#   '23365',
#   '3820',
#   '57595',
#   '7010',
#   '4306',
#   '284367',
#   '23243',
#   '119504',
#   '10126',
#   '7704',
#   '22927',
#   '8111',
#   '83877',
#   '7428',
#   '22859',
#   '94120',
#   '283876',
#   '165631',
#   '57118',
#   '163732',
#   '79595',
#   '311',
#   '10505'],
#  'no_selectVcomExpHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '5621',
#   '8644',
#   '3959',
#   '128553',
#   '8660',
#   '122525',
#   '7128',
#   '79673',
#   '23523',
#   '55153',
#   '284367',
#   '2209',
#   '10004',
#   '57595',
#   '643550',
#   '23031',
#   '645899',
#   '3418',
#   '92610',
#   '7010',
#   '3755',
#   '7528',
#   '5204',
#   '23365',
#   '8111',
#   '5996',
#   '4306',
#   '646195',
#   '10048',
#   '9792',
#   '6601',
#   '6890',
#   '3820',
#   '83931',
#   '53635',
#   '22927',
#   '11237',
#   '10975',
#   '6256',
#   '118788',
#   '56935',
#   '23135',
#   '28985',
#   '162466',
#   '80223',
#   '4335',
#   '2635',
#   '112495',
#   '163732',
#   '165631',
#   '9806',
#   '10277',
#   '7805',
#   '23243',
#   '6888',
#   '119504',
#   '23396',
#   '9770',
#   '10403',
#   '389816',
#   '54820',
#   '57210',
#   '83877',
#   '359845',
#   '23492',
#   '654121',
#   '51010',
#   '23097',
#   '90007',
#   '64174',
#   '5293',
#   '58190',
#   '81788',
#   '5684',
#   '10797',
#   '8408',
#   '91662',
#   '125950',
#   '55858',
#   '283871',
#   '28957',
#   '27242',
#   '23067',
#   '3707',
#   '5701',
#   '10987',
#   '60489',
#   '83719',
#   '3251',
#   '8648',
#   '87',
#   '57446',
#   '63875',
#   '983',
#   '55262',
#   '1408',
#   '5914',
#   '64411',
#   '7341',
#   '5989',
#   '57666',
#   '8019',
#   '55893',
#   '1729',
#   '56666',
#   '642197',
#   '728833',
#   '84440',
#   '9657',
#   '148479',
#   '22859',
#   '2217',
#   '57153',
#   '64386',
#   '343990',
#   '23060',
#   '54915',
#   '23130',
#   '7428',
#   '26119',
#   '10507',
#   '29954',
#   '3727',
#   '29888',
#   '29855',
#   '24142'],
#  'no_selectVcomExpHC_pcr': ['115362',
#   '4627',
#   '9232',
#   '2643',
#   '952',
#   '221504',
#   '155061',
#   '387934',
#   '4782',
#   '81603',
#   '10403',
#   '6907',
#   '83666',
#   '23048',
#   '343477',
#   '10286',
#   '10643',
#   '28985',
#   '3482',
#   '26030',
#   '64174',
#   '5479',
#   '55837',
#   '3428',
#   '29126',
#   '81788',
#   '25796',
#   '79591',
#   '23633',
#   '23604',
#   '125950',
#   '63940',
#   '7267',
#   '8408',
#   '7707',
#   '6668',
#   '2210',
#   '56666',
#   '5721',
#   '8445',
#   '87',
#   '5094',
#   '140885',
#   '9806',
#   '64411',
#   '400652',
#   '23492',
#   '5989',
#   '280655',
#   '1729',
#   '829',
#   '80223',
#   '23303',
#   '9739',
#   '9770',
#   '84548',
#   '6601',
#   '29097',
#   '10651',
#   '359845',
#   '2217',
#   '23135',
#   '306',
#   '93380',
#   '23368',
#   '1112',
#   '29855',
#   '4173',
#   '8019',
#   '5914',
#   '5686',
#   '118429',
#   '27351',
#   '79414',
#   '1831',
#   '7094',
#   '5578',
#   '55858',
#   '5701',
#   '23130',
#   '5293',
#   '28996',
#   '10004',
#   '56255',
#   '130074',
#   '23396',
#   '644310',
#   '157285',
#   '23067',
#   '7528',
#   '2618',
#   '339487',
#   '9657',
#   '10454',
#   '10048',
#   '84864',
#   '29089',
#   '3613',
#   '474338',
#   '644096',
#   '2771',
#   '10507',
#   '983',
#   '23558',
#   '387103',
#   '26505',
#   '647195',
#   '728833',
#   '10277',
#   '83879',
#   '6890',
#   '84440',
#   '58190',
#   '649214',
#   '146880',
#   '23097',
#   '60489',
#   '1639',
#   '343990',
#   '6433',
#   '80790',
#   '134957',
#   '6888',
#   '91663',
#   '79699',
#   '8648',
#   '92610',
#   '2788',
#   '9792',
#   '124460',
#   '115004',
#   '7805',
#   '29888',
#   '162466',
#   '1408',
#   '23060',
#   '54509',
#   '3707',
#   '9986',
#   '3727',
#   '83931',
#   '63875',
#   '3916',
#   '91662',
#   '4335',
#   '8328',
#   '654121',
#   '10635',
#   '3251',
#   '388753',
#   '4242',
#   '10797',
#   '26207',
#   '5684',
#   '54443',
#   '56935',
#   '55819',
#   '90007',
#   '54820'],
#  'no_selectVcomExpHC_plsr': ['9638',
#   '220042',
#   '79673',
#   '3959',
#   '5621',
#   '10643',
#   '122525',
#   '8660',
#   '8644',
#   '645899',
#   '10048',
#   '5204',
#   '23523',
#   '2209',
#   '128553',
#   '10975',
#   '57595',
#   '7128',
#   '56935',
#   '284367',
#   '10004',
#   '92610',
#   '9792',
#   '6601',
#   '3418',
#   '53635',
#   '7528',
#   '55153',
#   '643550',
#   '80223',
#   '646195',
#   '6890',
#   '63875',
#   '162466',
#   '5996',
#   '81788',
#   '118788',
#   '7805',
#   '23365',
#   '58190',
#   '23031',
#   '3755',
#   '7010',
#   '4306',
#   '51010',
#   '83931',
#   '5701',
#   '8408',
#   '163732',
#   '10277',
#   '165631',
#   '6888',
#   '11237',
#   '112495',
#   '23492',
#   '23135',
#   '54820',
#   '8111',
#   '83877',
#   '10987',
#   '28985',
#   '7341',
#   '2635',
#   '6256',
#   '28957',
#   '3820',
#   '4335',
#   '22927',
#   '9806',
#   '23243',
#   '10403',
#   '91662',
#   '8648',
#   '9770',
#   '119504',
#   '283871',
#   '389816',
#   '55262',
#   '90007',
#   '57210',
#   '359845',
#   '64174',
#   '3707',
#   '23396',
#   '642197',
#   '60489',
#   '125950',
#   '7428',
#   '23097',
#   '3251',
#   '57446',
#   '64411',
#   '4782',
#   '10797',
#   '55858',
#   '57666',
#   '23060',
#   '9657',
#   '83719',
#   '5293',
#   '27242',
#   '728833',
#   '983',
#   '654121',
#   '5989',
#   '5684',
#   '29954',
#   '5914',
#   '148479',
#   '8019',
#   '29888',
#   '1408',
#   '87',
#   '23067',
#   '26119',
#   '57153',
#   '29855',
#   '2217',
#   '64386',
#   '55893',
#   '10507',
#   '343990',
#   '81603',
#   '56666',
#   '84440',
#   '26505',
#   '1729',
#   '6907',
#   '116447',
#   '79414',
#   '3727',
#   '23130',
#   '54915',
#   '22859',
#   '24142',
#   '10651'],
#  'no_selectVcomFair_cor_no': ['9638'],
#  'no_selectVcomFair_cor_pcr': ['9638'],
#  'no_selectVcomFair_cor_sis': ['9638'],
#  'no_selectVcomFair_logisticFwd': ['9638'],
#  'no_selectVcomFair_no': ['10643', '23067', '9638'],
#  'no_selectVcomFair_sis': ['10643', '9638'],
#  'no_selectVcomHC_cor_cppls': ['9638',
#   '220042',
#   '5621',
#   '8644',
#   '122525',
#   '128553',
#   '55153',
#   '79673',
#   '23365',
#   '3820',
#   '57595',
#   '7010',
#   '4306',
#   '284367',
#   '23243',
#   '119504',
#   '10126',
#   '7704',
#   '22927',
#   '8111',
#   '83877',
#   '7428',
#   '22859',
#   '94120',
#   '283876',
#   '165631',
#   '57118',
#   '163732',
#   '79595',
#   '311',
#   '10505'],
#  'no_selectVcomHC_cor_plsr': ['9638',
#   '220042',
#   '5621',
#   '8644',
#   '122525',
#   '128553',
#   '55153',
#   '79673',
#   '23365',
#   '3820',
#   '57595',
#   '7010',
#   '4306',
#   '284367',
#   '23243',
#   '119504',
#   '10126',
#   '7704',
#   '22927',
#   '8111',
#   '83877',
#   '7428',
#   '22859',
#   '94120',
#   '283876',
#   '165631',
#   '57118',
#   '163732',
#   '79595',
#   '311',
#   '10505'],
#  'no_selectVcomHC_cppls': ['9638',
#   '220042',
#   '79673',
#   '3959',
#   '5621',
#   '10643',
#   '122525',
#   '8660',
#   '8644',
#   '645899',
#   '10048',
#   '5204',
#   '23523',
#   '2209',
#   '128553',
#   '10975',
#   '57595',
#   '7128',
#   '56935',
#   '284367',
#   '10004',
#   '92610',
#   '9792',
#   '6601',
#   '3418',
#   '53635',
#   '7528',
#   '55153',
#   '643550',
#   '80223',
#   '646195',
#   '6890',
#   '63875',
#   '162466',
#   '5996',
#   '81788',
#   '118788',
#   '7805',
#   '23365',
#   '58190',
#   '23031',
#   '3755',
#   '7010',
#   '4306',
#   '51010',
#   '83931',
#   '5701',
#   '8408',
#   '163732',
#   '10277',
#   '165631',
#   '6888',
#   '11237',
#   '112495',
#   '23492',
#   '23135',
#   '54820',
#   '8111',
#   '83877',
#   '10987',
#   '28985',
#   '7341',
#   '2635',
#   '6256',
#   '28957',
#   '3820',
#   '4335',
#   '22927',
#   '9806',
#   '23243',
#   '10403',
#   '91662',
#   '8648',
#   '9770',
#   '119504',
#   '283871',
#   '389816',
#   '55262',
#   '90007',
#   '57210',
#   '359845',
#   '64174',
#   '3707',
#   '23396',
#   '642197',
#   '60489',
#   '125950',
#   '7428',
#   '23097',
#   '3251',
#   '57446',
#   '64411',
#   '4782',
#   '10797',
#   '55858',
#   '57666',
#   '23060',
#   '9657',
#   '83719',
#   '5293',
#   '27242',
#   '728833',
#   '983',
#   '654121',
#   '5989',
#   '5684',
#   '29954',
#   '5914',
#   '148479',
#   '8019',
#   '29888',
#   '1408',
#   '87',
#   '23067',
#   '26119',
#   '57153',
#   '29855',
#   '2217',
#   '64386',
#   '55893',
#   '10507',
#   '343990',
#   '81603',
#   '56666',
#   '84440',
#   '26505',
#   '1729',
#   '6907',
#   '116447',
#   '79414',
#   '3727',
#   '23130',
#   '54915',
#   '22859',
#   '24142',
#   '10651'],
#  'no_selectVcomHC_pcr': ['4627',
#   '115362',
#   '2643',
#   '221504',
#   '9232',
#   '4782',
#   '81603',
#   '6907',
#   '952',
#   '155061',
#   '387934',
#   '10403',
#   '28985',
#   '83666',
#   '10286',
#   '3482',
#   '3428',
#   '26030',
#   '23633',
#   '7267',
#   '25796',
#   '23604',
#   '343477',
#   '23048',
#   '64174',
#   '79591',
#   '125950',
#   '10643',
#   '80223',
#   '29126',
#   '7707',
#   '55837',
#   '5989',
#   '5479',
#   '8408',
#   '6668',
#   '87',
#   '9806',
#   '2210',
#   '280655',
#   '84548',
#   '5094',
#   '56666',
#   '5721',
#   '64411',
#   '829',
#   '10651',
#   '81788',
#   '9739',
#   '1729',
#   '23135',
#   '8445',
#   '1831',
#   '2217',
#   '93380',
#   '23492',
#   '23396',
#   '359845',
#   '1112',
#   '63940',
#   '140885',
#   '130074',
#   '5578',
#   '306',
#   '8019',
#   '9770',
#   '79414',
#   '23303',
#   '6601',
#   '5914',
#   '5293',
#   '29097',
#   '23368',
#   '7094',
#   '23067',
#   '4173',
#   '118429',
#   '2618',
#   '10454',
#   '10048',
#   '29855',
#   '5701',
#   '339487',
#   '7528',
#   '23558',
#   '9657',
#   '644310',
#   '26505',
#   '27351',
#   '5686',
#   '84440',
#   '84864',
#   '29089',
#   '55858',
#   '644096',
#   '387103',
#   '474338',
#   '23097',
#   '10507',
#   '157285',
#   '28996',
#   '983',
#   '343990',
#   '163732',
#   '2771',
#   '6888',
#   '6890',
#   '10277',
#   '23429',
#   '60489',
#   '58190',
#   '649214',
#   '134957',
#   '647195',
#   '9792',
#   '3613',
#   '7805',
#   '146880',
#   '728833',
#   '83879',
#   '23130',
#   '23060',
#   '124460',
#   '10431',
#   '91663',
#   '2788',
#   '115004',
#   '6433',
#   '80790',
#   '92610',
#   '54509',
#   '3707',
#   '1639',
#   '29888',
#   '162466',
#   '1408',
#   '9986',
#   '79699',
#   '63875',
#   '83931',
#   '3916',
#   '8648',
#   '10635',
#   '8328',
#   '94120',
#   '3251',
#   '10797',
#   '3727',
#   '54443',
#   '4335',
#   '91662',
#   '64386',
#   '4242',
#   '654121',
#   '5684',
#   '56935',
#   '54820',
#   '2635',
#   '55819'],
#  'no_selectVcomHC_plsr': ['9638',
#   '220042',
#   '10643',
#   '5621',
#   '8644',
#   '3959',
#   '128553',
#   '8660',
#   '122525',
#   '7128',
#   '79673',
#   '23523',
#   '55153',
#   '284367',
#   '2209',
#   '10004',
#   '57595',
#   '643550',
#   '23031',
#   '645899',
#   '3418',
#   '92610',
#   '7010',
#   '3755',
#   '7528',
#   '5204',
#   '23365',
#   '8111',
#   '5996',
#   '4306',
#   '646195',
#   '10048',
#   '9792',
#   '6601',
#   '6890',
#   '3820',
#   '83931',
#   '53635',
#   '22927',
#   '11237',
#   '10975',
#   '6256',
#   '118788',
#   '56935',
#   '23135',
#   '28985',
#   '162466',
#   '80223',
#   '4335',
#   '2635',
#   '112495',
#   '163732',
#   '165631',
#   '9806',
#   '10277',
#   '7805',
#   '23243',
#   '6888',
#   '119504',
#   '23396',
#   '9770',
#   '10403',
#   '389816',
#   '54820',
#   '57210',
#   '83877',
#   '359845',
#   '23492',
#   '654121',
#   '51010',
#   '23097',
#   '90007',
#   '64174',
#   '5293',
#   '58190',
#   '81788',
#   '5684',
#   '10797',
#   '8408',
#   '91662',
#   '125950',
#   '55858',
#   '283871',
#   '28957',
#   '27242',
#   '23067',
#   '3707',
#   '5701',
#   '10987',
#   '60489',
#   '83719',
#   '3251',
#   '8648',
#   '87',
#   '57446',
#   '63875',
#   '983',
#   '55262',
#   '1408',
#   '5914',
#   '64411',
#   '7341',
#   '5989',
#   '57666',
#   '8019',
#   '55893',
#   '1729',
#   '56666',
#   '642197',
#   '728833',
#   '84440',
#   '9657',
#   '148479',
#   '22859',
#   '2217',
#   '57153',
#   '64386',
#   '343990',
#   '23060',
#   '54915',
#   '23130',
#   '7428',
#   '26119',
#   '10507',
#   '29954',
#   '3727',
#   '29888',
#   '29855',
#   '24142'],
#  'no_selectVnotComExpHC_cor_cppls': ['9638',
#   '220042',
#   '5621',
#   '8644',
#   '122525',
#   '128553',
#   '7128',
#   '55153',
#   '79673',
#   '23365',
#   '3820',
#   '57595',
#   '7010',
#   '23401',
#   '284367',
#   '23243',
#   '4306',
#   '119504',
#   '10126',
#   '7704',
#   '22927',
#   '8111',
#   '83877',
#   '7428',
#   '22859',
#   '94120',
#   '441168',
#   '283876',
#   '165631',
#   '57118',
#   '163732',
#   '9454',
#   '311',
#   '10505'],
#  'no_selectVnotComExpHC_cor_pcr': ['8607',
#   '163732',
#   '1380',
#   '26207',
#   '79673',
#   '113189',
#   '10975',
#   '9454',
#   '10505',
#   '259197',
#   '2788',
#   '8111',
#   '165631',
#   '57118',
#   '10126',
#   '94120',
#   '22859',
#   '10109',
#   '7704',
#   '3597',
#   '65993',
#   '140803',
#   '4306',
#   '7428',
#   '283876',
#   '6789'],
#  'no_selectVnotComExpHC_cor_plsr': ['9638',
#   '220042',
#   '5621',
#   '8644',
#   '122525',
#   '128553',
#   '7128',
#   '55153',
#   '79673',
#   '23365',
#   '3820',
#   '57595',
#   '7010',
#   '23401',
#   '284367',
#   '23243',
#   '4306',
#   '119504',
#   '10126',
#   '7704',
#   '22927',
#   '8111',
#   '83877',
#   '7428',
#   '22859',
#   '94120',
#   '441168',
#   '283876',
#   '165631',
#   '57118',
#   '163732',
#   '9454',
#   '311',
#   '10505'],
#  'no_selectVnotComExpHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '5621',
#   '8644',
#   '3959',
#   '122525',
#   '128553',
#   '8660',
#   '7128',
#   '23523',
#   '79673',
#   '55153',
#   '284367',
#   '2209',
#   '10004',
#   '23031',
#   '57595',
#   '7010',
#   '645899',
#   '3418',
#   '643550',
#   '92610',
#   '3755',
#   '7528',
#   '23365',
#   '8111',
#   '5204',
#   '4306',
#   '5996',
#   '646195',
#   '10048',
#   '9792',
#   '6601',
#   '83931',
#   '3820',
#   '6890',
#   '22927',
#   '53635',
#   '10975',
#   '11237',
#   '6256',
#   '56935',
#   '162466',
#   '28985',
#   '80223',
#   '23135',
#   '118788',
#   '4335',
#   '9806',
#   '163732',
#   '165631',
#   '23243',
#   '112495',
#   '7805',
#   '2635',
#   '10277',
#   '402415',
#   '6888',
#   '119504',
#   '23396',
#   '10403',
#   '9770',
#   '51099',
#   '83877',
#   '57210',
#   '6691',
#   '389816',
#   '54820',
#   '654121',
#   '359845',
#   '23492',
#   '23097',
#   '5293',
#   '51010',
#   '90007',
#   '64174',
#   '58190',
#   '81788',
#   '91662',
#   '10797',
#   '5684',
#   '125950',
#   '8408',
#   '55858',
#   '8648',
#   '3707',
#   '23067',
#   '983',
#   '283871',
#   '83719',
#   '28957',
#   '27242',
#   '5701',
#   '60489',
#   '3251',
#   '10987',
#   '87',
#   '1408',
#   '10635',
#   '5914',
#   '55262',
#   '64411',
#   '57446',
#   '57666',
#   '9919',
#   '11322',
#   '7341',
#   '5989',
#   '8019',
#   '1729',
#   '55893',
#   '56666',
#   '728833',
#   '84440',
#   '2217',
#   '148479',
#   '9657',
#   '22859',
#   '57153',
#   '64386',
#   '54915',
#   '26119',
#   '343990',
#   '387103',
#   '2210',
#   '7428',
#   '23060',
#   '29855',
#   '81603',
#   '10507',
#   '29888',
#   '3727',
#   '8427',
#   '24142'],
#  'no_selectVnotComExpHC_plsr': ['9638',
#   '220042',
#   '10643',
#   '5621',
#   '8644',
#   '3959',
#   '122525',
#   '128553',
#   '8660',
#   '7128',
#   '23523',
#   '79673',
#   '55153',
#   '284367',
#   '2209',
#   '10004',
#   '23031',
#   '57595',
#   '7010',
#   '645899',
#   '3418',
#   '643550',
#   '92610',
#   '3755',
#   '7528',
#   '23365',
#   '8111',
#   '5204',
#   '4306',
#   '5996',
#   '646195',
#   '10048',
#   '9792',
#   '6601',
#   '83931',
#   '3820',
#   '6890',
#   '22927',
#   '53635',
#   '10975',
#   '11237',
#   '6256',
#   '56935',
#   '162466',
#   '28985',
#   '80223',
#   '23135',
#   '118788',
#   '4335',
#   '9806',
#   '163732',
#   '165631',
#   '23243',
#   '112495',
#   '7805',
#   '2635',
#   '10277',
#   '402415',
#   '6888',
#   '119504',
#   '23396',
#   '10403',
#   '9770',
#   '51099',
#   '83877',
#   '57210',
#   '6691',
#   '389816',
#   '54820',
#   '654121',
#   '359845',
#   '23492',
#   '23097',
#   '5293',
#   '51010',
#   '90007',
#   '64174',
#   '58190',
#   '81788',
#   '91662',
#   '10797',
#   '5684',
#   '125950',
#   '8408',
#   '55858',
#   '8648',
#   '3707',
#   '23067',
#   '983',
#   '283871',
#   '83719',
#   '28957',
#   '27242',
#   '5701',
#   '60489',
#   '3251',
#   '10987',
#   '87',
#   '1408',
#   '10635',
#   '5914',
#   '55262',
#   '64411',
#   '57446',
#   '57666',
#   '9919',
#   '11322',
#   '7341',
#   '5989',
#   '8019',
#   '1729',
#   '55893',
#   '56666',
#   '728833',
#   '84440',
#   '2217',
#   '148479',
#   '9657',
#   '22859',
#   '57153',
#   '64386',
#   '6907',
#   '54915',
#   '26119',
#   '343990',
#   '387103',
#   '116447',
#   '2210',
#   '7428',
#   '23060',
#   '29855',
#   '81603',
#   '10507',
#   '29888',
#   '3727',
#   '10651',
#   '8427',
#   '26505',
#   '24142'],
#  'no_selectVnotComFair_cor_pcr': [],
#  'no_selectVnotComFair_logisticFwd': ['10643', '9638'],
#  'no_selectVnotComFair_no': ['10643', '9638'],
#  'no_selectVnotComFair_sis': ['10643', '9638'],
#  'no_selectVnotComHC_cor_cppls': ['9638',
#   '220042',
#   '5621',
#   '8644',
#   '122525',
#   '128553',
#   '7128',
#   '55153',
#   '79673',
#   '23365',
#   '3820',
#   '57595',
#   '7010',
#   '23401',
#   '284367',
#   '23243',
#   '4306',
#   '119504',
#   '10126',
#   '7704',
#   '22927',
#   '8111',
#   '83877',
#   '7428',
#   '22859',
#   '94120',
#   '441168',
#   '283876',
#   '165631',
#   '57118',
#   '163732',
#   '9454',
#   '311',
#   '10505'],
#  'no_selectVnotComHC_cor_pcr': ['2788',
#   '26207',
#   '79673',
#   '113189',
#   '1380',
#   '55819',
#   '22859',
#   '8607',
#   '163732',
#   '9454',
#   '3597',
#   '10109',
#   '94120',
#   '10975',
#   '57118',
#   '4306',
#   '10505',
#   '311',
#   '6789',
#   '259197',
#   '165631',
#   '10126'],
#  'no_selectVnotComHC_cor_plsr': ['9638',
#   '220042',
#   '5621',
#   '8644',
#   '122525',
#   '128553',
#   '7128',
#   '55153',
#   '79673',
#   '23365',
#   '3820',
#   '57595',
#   '7010',
#   '23401',
#   '284367',
#   '23243',
#   '4306',
#   '119504',
#   '10126',
#   '7704',
#   '22927',
#   '8111',
#   '83877',
#   '7428',
#   '22859',
#   '94120',
#   '441168',
#   '283876',
#   '165631',
#   '57118',
#   '163732',
#   '9454',
#   '311',
#   '10505'],
#  'no_selectVnotComHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '5621',
#   '8644',
#   '3959',
#   '122525',
#   '128553',
#   '8660',
#   '7128',
#   '23523',
#   '79673',
#   '55153',
#   '284367',
#   '2209',
#   '10004',
#   '23031',
#   '57595',
#   '7010',
#   '645899',
#   '3418',
#   '643550',
#   '92610',
#   '3755',
#   '7528',
#   '23365',
#   '8111',
#   '5204',
#   '4306',
#   '5996',
#   '646195',
#   '10048',
#   '9792',
#   '6601',
#   '83931',
#   '3820',
#   '6890',
#   '53635',
#   '10975',
#   '11237',
#   '6256',
#   '56935',
#   '162466',
#   '28985',
#   '80223',
#   '23135',
#   '118788',
#   '4335',
#   '9806',
#   '163732',
#   '165631',
#   '23243',
#   '112495',
#   '7805',
#   '2635',
#   '10277',
#   '402415',
#   '6888',
#   '119504',
#   '23396',
#   '10403',
#   '9770',
#   '51099',
#   '83877',
#   '57210',
#   '6691',
#   '389816',
#   '54820',
#   '654121',
#   '359845',
#   '23492',
#   '23097',
#   '5293',
#   '51010',
#   '90007',
#   '64174',
#   '58190',
#   '81788',
#   '91662',
#   '10797',
#   '5684',
#   '125950',
#   '8408',
#   '55858',
#   '8648',
#   '3707',
#   '597',
#   '23067',
#   '983',
#   '283871',
#   '83719',
#   '28957',
#   '27242',
#   '5701',
#   '60489',
#   '3251',
#   '10987',
#   '87',
#   '1408',
#   '10635',
#   '5914',
#   '55262',
#   '64411',
#   '57446',
#   '57666',
#   '9919',
#   '11322',
#   '7341',
#   '5989',
#   '8019',
#   '1729',
#   '55893',
#   '56666',
#   '728833',
#   '84440',
#   '2217',
#   '148479',
#   '9657',
#   '22859',
#   '57153',
#   '64386',
#   '54915',
#   '26119',
#   '387103',
#   '2210',
#   '7428',
#   '23060',
#   '29855',
#   '10507',
#   '29888',
#   '3727',
#   '10651',
#   '24142'],
#  'no_selectVnotComHC_grn3_logisticFwd': [],
# ...
#   '6487',
#   '29127',
#   '140710',
#   '55759',
#   '10207',
#   '9919',
#   '64333',
#   '7903',
#   '651816',
#   '400652',
#   '56935',
#   '57153',
#   '5684',
#   '54915',
#   '5701',
#   '9993',
#   '730994',
#   '26152',
#   '28971',
#   '4650',
#   '1666',
#   '7090',
#   '55500',
#   '54815',
#   '11322',
#   '8660',
#   '57446',
#   '53635',
#   '6850',
#   '474338',
#   '387921',
#   '527',
#   '1639',
#   '388753',
#   '146225',
#   '9846',
#   '51010',
#   '83719',
#   '280655',
#   '1477',
#   '118',
#   '146880',
#   '135114',
#   '4084',
#   '161882',
#   '2961',
#   '55854',
#   '29071',
#   '54955',
#   '26020',
#   '2323',
#   '92610',
#   '1408',
#   '5876',
#   '60343',
#   '27257',
#   '22924',
#   '81565',
#   '649209',
#   '118432',
#   '55848',
#   '29922',
#   '55731',
#   '1052',
#   '4242',
#   '643550',
#   '8841',
#   '140606',
#   '23130',
#   '63035',
#   '7536',
#   '55819',
#   '10505',
#   '26207'],
#  'varImportance_selectVnotComExpHC_plsr': ['9638',
#   '220042',
#   '10461',
#   '5621',
#   '10643',
#   '8644',
#   '50808',
#   '7128',
#   '3800',
#   '3959',
#   '403313',
#   '128553',
#   '122525',
#   '374920',
#   '284367',
#   '8660',
#   '79673',
#   '23523',
#   '7010',
#   '57595',
#   '92610',
#   '574029',
#   '3755',
#   '4222',
#   '55153',
#   '643550',
#   '10004',
#   '23031',
#   '645899',
#   '387837',
#   '3418',
#   '642369',
#   '694',
#   '2209',
#   '5204',
#   '8111',
#   '22927',
#   '79651',
#   '7528',
#   '5996',
#   '23365',
#   '646195',
#   '2999',
#   '4736',
#   '6601',
#   '7572',
#   '120103',
#   '57168',
#   '126695',
#   '3820',
#   '83931',
#   '9792',
#   '4306',
#   '6890',
#   '10975',
#   '642749',
#   '85012',
#   '162466',
#   '7805',
#   '9750',
#   '56833',
#   '4335',
#   '5730',
#   '53635',
#   '10048',
#   '7525',
#   '28985',
#   '56935',
#   '6789',
#   '2947',
#   '11237',
#   '118788',
#   '728715',
#   '402415',
#   '728744',
#   '23243',
#   '119504',
#   '27330',
#   '163732',
#   '80223',
#   '22803',
#   '6208',
#   '112495',
#   '165631',
#   '6256',
#   '9806',
#   '343099',
#   '7702',
#   '6691',
#   '441168',
#   '55049',
#   '2635',
#   '118432',
#   '57007',
#   '5330',
#   '23396',
#   '9254',
#   '2788',
#   '266747',
#   '23135',
#   '10403',
#   '5696',
#   '51099',
#   '83877',
#   '6888',
#   '10477',
#   '54741',
#   '359845',
#   '5293',
#   '4090',
#   '58190',
#   '9770',
#   '5863',
#   '163233',
#   '81788',
#   '10277',
#   '10897',
#   '389816',
#   '654121',
#   '23097',
#   '57210',
#   '10797',
#   '54820',
#   '57161',
#   '2932',
#   '51010',
#   '8408',
#   '93380',
#   '5684',
#   '983',
#   '6399',
#   '5796',
#   '56942',
#   '4650',
#   '142891',
#   '5537',
#   '23053',
#   '55752',
#   '79143',
#   '58476',
#   '51315',
#   '9637',
#   '90007',
#   '51053',
#   '3251',
#   '55022',
#   '1112',
#   '84259',
#   '9757',
#   '643997',
#   '57666',
#   '60489',
#   '8648',
#   '3838',
#   '1387',
#   '5701',
#   '7094',
#   '9739',
#   '91662',
#   '3916',
#   '3707',
#   '23492',
#   '653157',
#   '63875',
#   '597',
#   '5914',
#   '28957',
#   '87',
#   '27242',
#   '10635',
#   '80256',
#   '23214',
#   '83719',
#   '28977',
#   '10987',
#   '64975',
#   '1729',
#   '125950',
#   '5111',
#   '80183',
#   '130074',
#   '440551',
#   '9919',
#   '55858',
#   '1408',
#   '9766',
#   '27292',
#   '10247',
#   '5989',
#   '55113',
#   '11322',
#   '9993',
#   '64411',
#   '23067',
#   '55759',
#   '81565',
#   '84919',
#   '55262',
#   '283871',
#   '27161',
#   '6668',
#   '7090',
#   '64174',
#   '2946',
#   '7341',
#   '9612',
#   '728833',
#   '3609',
#   '3632',
#   '64333',
#   '6629',
#   '29078',
#   '55854',
#   '56255',
#   '92162',
#   '2664',
#   '8522',
#   '11031',
#   '8019',
#   '3308',
#   '23558',
#   '55201',
#   '57446',
#   '1523',
#   '4122',
#   '10431',
#   '84440',
#   '29089',
#   '55500',
#   '79023',
#   '55967',
#   '10507',
#   '642197',
#   '4627',
#   '63035',
#   '391257',
#   '148479',
#   '29097',
#   '29855',
#   '1666',
#   '1815',
#   '84557',
#   '55010',
#   '22883',
#   '56905',
#   '55893',
#   '54962',
#   '2171',
#   '387103',
#   '916',
#   '1033',
#   '153222',
#   '207',
#   '9181',
#   '26052',
#   '9134',
#   '3727',
#   '23130',
#   '55108',
#   '81857',
#   '146880',
#   '55540',
#   '5814',
#   '115207',
#   '140885',
#   '2210',
#   '2217',
#   '1477',
#   '51128',
#   '57153',
#   '26119',
#   '23368',
#   '64386',
#   '27043',
#   '51203',
#   '81603',
#   '305',
#   '114769',
#   '9318',
#   '8986',
#   '645351',
#   '10651',
#   '7462',
#   '1111',
#   '378708',
#   '118429',
#   '157285',
#   '6609',
#   '83879',
#   '730994',
#   '9657',
#   '7444',
#   '3161',
#   '57140',
#   '642031',
#   '22859',
#   '7428',
#   '10283',
#   '5634',
#   '387934',
#   '79893',
#   '699',
#   '51258',
#   '116447',
#   '29954',
#   '337976',
#   '23060',
#   '94120',
#   '5298',
#   '54915',
#   '29888',
#   '56666',
#   '644310',
#   '752',
#   '5902',
#   '6709',
#   '3324',
#   '7267',
#   '6907',
#   '219771',
#   '3300',
#   '1639',
#   '23351',
#   '5686',
#   '26505',
#   '79699',
#   '343477',
#   '51111',
#   '1822',
#   '9060',
#   '9220',
#   '343990',
#   '24142',
#   '2618',
#   '57118',
#   '55165',
#   '9232',
#   '23256',
#   '5984',
#   '29889',
#   '29922',
#   '91663',
#   '8427',
#   '4782',
#   '57458',
#   '6201',
#   '9989',
#   '10908',
#   '474338',
#   '114294',
#   '26228',
#   '79414',
#   '9261',
#   '26272',
#   '349236',
#   '140710',
#   '115004',
#   '124460',
#   '3678',
#   '64151',
#   '84548',
#   '29924',
#   '9019',
#   '7879',
#   '2643',
#   '7704',
#   '93129',
#   '861',
#   '54955',
#   '55092',
#   '596',
#   '28996',
#   '3832',
#   '118813',
#   '154075',
#   '54662',
#   '92703',
#   '79591',
#   '952',
#   '10733',
#   '23633',
#   '6433',
#   '57659',
#   '55810',
#   '388753',
#   '55789',
#   '4331',
#   '352954',
#   '135114'],
#  'varImportance_selectVnotComFair_cor_pcr': [],
#  'varImportance_selectVnotComFair_logisticFwd': ['10643', '9638'],
#  'varImportance_selectVnotComFair_no': ['10643', '9638'],
#  'varImportance_selectVnotComFair_sis': ['10643', '9638'],
#  'varImportance_selectVnotComHC_cor_zscore_pcr': ['8111',
#   '163732',
#   '57595',
#   '9638'],
#  'varImportance_zscore_cor_cppls': ['220042',
#   '10461',
#   '9638',
#   '50808',
#   '128553',
#   '157285',
#   '5730',
#   '55049',
#   '7128',
#   '23401',
#   '91663',
#   '3820',
#   '114294',
#   '5996',
#   '9019',
#   '163732',
#   '57595',
#   '8644',
#   '283871',
#   '57118',
#   '4306',
#   '7704',
#   '80790',
#   '7428',
#   '55893',
#   '8111',
#   '283876',
#   '9060'],
#  'varImportance_zscore_cor_plsr': ['220042',
#   '10461',
#   '9638',
#   '50808',
#   '128553',
#   '157285',
#   '5730',
#   '55049',
#   '7128',
#   '23401',
#   '91663',
#   '3820',
#   '114294',
#   '5996',
#   '9019',
#   '163732',
#   '57595',
#   '8644',
#   '283871',
#   '57118',
#   '4306',
#   '7704',
#   '80790',
#   '7428',
#   '55893',
#   '8111',
#   '283876',
#   '9060'],
#  'varImportance_zscore_cppls': ['220042',
#   '9638',
#   '10643',
#   '10461',
#   '8660',
#   '128553',
#   '23523',
#   '50808',
#   '7128',
#   '8644',
#   '643550',
#   '6256',
#   '7528',
#   '5996',
#   '343099',
#   '10004',
#   '11237',
#   '112495',
#   '57595',
#   '3418',
#   '23135',
#   '53635',
#   '10277',
#   '162466',
#   '4306',
#   '2209',
#   '23031',
#   '5730',
#   '54820',
#   '3820',
#   '10987',
#   '8408',
#   '163732',
#   '10048',
#   '51010',
#   '83931',
#   '28985',
#   '9792',
#   '2635',
#   '6890',
#   '5701',
#   '57446',
#   '57210',
#   '23492',
#   '4335',
#   '55858',
#   '283871',
#   '28957',
#   '80223',
#   '22803',
#   '343990',
#   '389816',
#   '55049',
#   '56935',
#   '90007',
#   '359845',
#   '23067',
#   '10403',
#   '64411',
#   '642197',
#   '1408',
#   '441168',
#   '5914',
#   '81788',
#   '9657',
#   '51258',
#   '23060',
#   '23558',
#   '57161',
#   '6907',
#   '114294',
#   '29089',
#   '91662',
#   '27351',
#   '57666',
#   '728833',
#   '26505',
#   '146880',
#   '5578',
#   '94120',
#   '2217',
#   '6201',
#   '7428',
#   '28996',
#   '4782',
#   '387103'],
#  'varImportance_zscore_plsr': ['220042',
#   '9638',
#   '10643',
#   '10461',
#   '8660',
#   '128553',
#   '23523',
#   '50808',
#   '3959',
#   '7128',
#   '8644',
#   '643550',
#   '6256',
#   '7528',
#   '5996',
#   '343099',
#   '10004',
#   '11237',
#   '112495',
#   '57595',
#   '3418',
#   '23135',
#   '53635',
#   '10277',
#   '162466',
#   '4306',
#   '23031',
#   '5730',
#   '64174',
#   '54820',
#   '3820',
#   '10987',
#   '8408',
#   '163732',
#   '10048',
#   '8111',
#   '51010',
#   '83931',
#   '28985',
#   '9792',
#   '2635',
#   '6890',
#   '5701',
#   '57446',
#   '57210',
#   '23492',
#   '9770',
#   '4335',
#   '55858',
#   '283871',
#   '28957',
#   '80223',
#   '22803',
#   '343990',
#   '389816',
#   '56935',
#   '90007',
#   '359845',
#   '23067',
#   '56666',
#   '10403',
#   '64411',
#   '642197',
#   '1408',
#   '441168',
#   '5914',
#   '81788',
#   '9657',
#   '51258',
#   '23060',
#   '83719',
#   '23558',
#   '10431',
#   '57161',
#   '6907',
#   '114294',
#   '29089',
#   '23401',
#   '1729',
#   '91662',
#   '5863',
#   '27351',
#   '57666',
#   '728833',
#   '26505',
#   '55893',
#   '3727',
#   '91663',
#   '5578',
#   '94120',
#   '2217',
#   '7428',
#   '28996',
#   '4782',
#   '387103'],
#  'var_selectVcomExpHC_cor_zscore_pcr': ['4306',
#   '7128',
#   '55893',
#   '9638',
#   '57595',
#   '163732'],
#  'var_selectVcomExpHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '7128',
#   '8660',
#   '3959',
#   '3755',
#   '57595',
#   '2209',
#   '5996',
#   '120103',
#   '3418',
#   '7528',
#   '23523',
#   '4306',
#   '163732',
#   '2947',
#   '9792',
#   '23031',
#   '6890',
#   '80223',
#   '9806',
#   '23067',
#   '56935',
#   '3820',
#   '118788',
#   '728744',
#   '441168',
#   '389816',
#   '2635',
#   '11237',
#   '283871',
#   '6256',
#   '23135',
#   '27242',
#   '359845',
#   '23492',
#   '162466',
#   '119504',
#   '112495',
#   '6601',
#   '28985',
#   '83931',
#   '8648',
#   '400652',
#   '23396',
#   '53635',
#   '57210',
#   '4335',
#   '10403',
#   '7805',
#   '9657',
#   '23097',
#   '9770',
#   '64174',
#   '55858',
#   '54820',
#   '654121',
#   '90007',
#   '125950',
#   '29097',
#   '51010',
#   '7341',
#   '391257',
#   '10797',
#   '91662',
#   '5293',
#   '5684',
#   '64411',
#   '8408',
#   '3707',
#   '60489',
#   '3251',
#   '55262',
#   '83719',
#   '5914',
#   '983',
#   '87',
#   '58190',
#   '5989',
#   '140885',
#   '81788',
#   '56666',
#   '8019',
#   '1729',
#   '84440',
#   '56905',
#   '57666',
#   '26119',
#   '6907',
#   '57153',
#   '29888',
#   '24142',
#   '10507',
#   '29855'],
#  'var_selectVcomExpHC_grn3Cntl_cor_cppls': [],
#  'var_selectVcomExpHC_grn3Cntl_cor_no': [],
#  'var_selectVcomExpHC_grn3Cntl_cor_plsr': [],
#  'var_selectVcomExpHC_grn3Cntl_cppls': [],
#  'var_selectVcomExpHC_grn3Cntl_no': [],
#  'var_selectVcomExpHC_grn3Cntl_plsr': [],
#  'var_selectVcomExpHC_plsr': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '7128',
#   '8660',
#   '3959',
#   '3755',
#   '57595',
#   '2209',
#   '5996',
#   '120103',
#   '3418',
#   '7528',
#   '23523',
#   '4306',
#   '163732',
#   '2947',
#   '9792',
#   '23031',
#   '6890',
#   '80223',
#   '9806',
#   '23067',
#   '56935',
#   '3820',
#   '118788',
#   '728744',
#   '441168',
#   '389816',
#   '2635',
#   '11237',
#   '283871',
#   '6256',
#   '23135',
#   '27242',
#   '359845',
#   '23492',
#   '162466',
#   '119504',
#   '112495',
#   '6601',
#   '28985',
#   '83931',
#   '8648',
#   '400652',
#   '23396',
#   '53635',
#   '57210',
#   '4335',
#   '10403',
#   '7805',
#   '9657',
#   '23097',
#   '9770',
#   '64174',
#   '55858',
#   '54820',
#   '654121',
#   '90007',
#   '125950',
#   '29097',
#   '51010',
#   '7341',
#   '391257',
#   '10797',
#   '91662',
#   '5293',
#   '5684',
#   '64411',
#   '8408',
#   '3707',
#   '60489',
#   '3251',
#   '55262',
#   '83719',
#   '5914',
#   '983',
#   '87',
#   '58190',
#   '5989',
#   '140885',
#   '81788',
#   '56666',
#   '8019',
#   '1729',
#   '84440',
#   '56905',
#   '57666',
#   '26119',
#   '6907',
#   '57153',
#   '29888',
#   '24142',
#   '10507',
#   '29855'],
#  'var_selectVcomFair_cor_cppls': ['9638'],
#  'var_selectVcomFair_cor_no': ['9638'],
#  'var_selectVcomFair_cor_pcr': ['9638'],
#  'var_selectVcomFair_cor_plsr': ['9638'],
#  'var_selectVcomFair_cor_sis': ['9638'],
#  'var_selectVcomFair_logisticFwd': ['10643', '9638'],
#  'var_selectVcomFair_no': ['10643', '23067', '9638'],
#  'var_selectVcomFair_sis': ['10643', '23067', '9638'],
#  'var_selectVcomHC_grn3Cntl_cor_cppls': [],
#  'var_selectVcomHC_grn3Cntl_cor_no': [],
#  'var_selectVcomHC_grn3Cntl_cor_plsr': [],
#  'var_selectVcomHC_grn3Cntl_cppls': [],
#  'var_selectVcomHC_grn3Cntl_no': [],
#  'var_selectVcomHC_grn3Cntl_plsr': [],
#  'var_selectVnotComExpHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '7128',
#   '3959',
#   '8660',
#   '3755',
#   '57595',
#   '2209',
#   '5996',
#   '120103',
#   '3418',
#   '7528',
#   '23523',
#   '4306',
#   '9792',
#   '2947',
#   '163732',
#   '23031',
#   '9806',
#   '80223',
#   '6890',
#   '56935',
#   '23067',
#   '3820',
#   '728744',
#   '441168',
#   '118788',
#   '389816',
#   '2635',
#   '11237',
#   '283871',
#   '6256',
#   '23135',
#   '119504',
#   '23492',
#   '27242',
#   '359845',
#   '162466',
#   '8648',
#   '6601',
#   '83931',
#   '28985',
#   '112495',
#   '400652',
#   '23396',
#   '4335',
#   '53635',
#   '57210',
#   '7805',
#   '10403',
#   '23097',
#   '9770',
#   '9657',
#   '64174',
#   '654121',
#   '55858',
#   '54820',
#   '90007',
#   '125950',
#   '391257',
#   '91662',
#   '5293',
#   '29097',
#   '51010',
#   '10797',
#   '7341',
#   '64411',
#   '5684',
#   '8408',
#   '3707',
#   '4650',
#   '983',
#   '60489',
#   '3251',
#   '83719',
#   '55262',
#   '5914',
#   '87',
#   '58190',
#   '5989',
#   '81788',
#   '8019',
#   '140885',
#   '56666',
#   '1729',
#   '343990',
#   '57666',
#   '56905',
#   '84440',
#   '57118',
#   '91663',
#   '26119',
#   '6907',
#   '57153',
#   '29888',
#   '24142'],
#  'var_selectVnotComExpHC_grn3Cntl_logisticFwd': [],
#  'var_selectVnotComExpHC_grn3Cntl_no': [],
#  'var_selectVnotComExpHC_grn3Cntl_sis': [],
#  'var_selectVnotComExpHC_grn3_cor_no': [],
#  'var_selectVnotComExpHC_plsr': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '7128',
#   '3959',
#   '8660',
#   '3755',
#   '57595',
#   '2209',
#   '5996',
#   '120103',
#   '3418',
#   '7528',
#   '23523',
#   '4306',
#   '9792',
#   '2947',
#   '163732',
#   '23031',
#   '9806',
#   '80223',
#   '6890',
#   '56935',
#   '23067',
#   '3820',
#   '728744',
#   '441168',
#   '118788',
#   '389816',
#   '2635',
#   '11237',
#   '283871',
#   '6256',
#   '23135',
#   '119504',
#   '23492',
#   '27242',
#   '359845',
#   '162466',
#   '8648',
#   '6601',
#   '83931',
#   '28985',
#   '112495',
#   '400652',
#   '23396',
#   '4335',
#   '53635',
#   '57210',
#   '7805',
#   '10403',
#   '23097',
#   '9770',
#   '9657',
#   '64174',
#   '654121',
#   '55858',
#   '54820',
#   '90007',
#   '125950',
#   '391257',
#   '91662',
#   '5293',
#   '29097',
#   '51010',
#   '10797',
#   '7341',
#   '64411',
#   '5684',
#   '8408',
#   '3707',
#   '4650',
#   '983',
#   '60489',
#   '3251',
#   '83719',
#   '55262',
#   '5914',
#   '87',
#   '58190',
#   '5989',
#   '81788',
#   '8019',
#   '140885',
#   '56666',
#   '1729',
#   '343990',
#   '57666',
#   '56905',
#   '84440',
#   '57118',
#   '91663',
#   '26119',
#   '6907',
#   '57153',
#   '29888',
#   '24142'],
#  'var_selectVnotComFair_cor_cppls': ['9638'],
#  'var_selectVnotComFair_cor_logisticFwd': ['9638'],
#  'var_selectVnotComFair_cor_no': ['9638'],
#  'var_selectVnotComFair_cor_pcr': ['9638'],
#  'var_selectVnotComFair_cor_plsr': ['9638'],
#  'var_selectVnotComFair_cor_sis': ['9638'],
#  'var_selectVnotComFair_cppls': ['9638'],
#  'var_selectVnotComFair_logisticFwd': ['10643', '9638'],
#  'var_selectVnotComFair_no': ['10643', '9638'],
#  'var_selectVnotComFair_plsr': ['9638'],
#  'var_selectVnotComFair_sis': ['10643', '9638'],
#  'var_selectVnotComHC_cppls': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '8660',
#   '3959',
#   '7128',
#   '2209',
#   '57595',
#   '5996',
#   '3418',
#   '3755',
#   '23523',
#   '7528',
#   '6890',
#   '4306',
#   '23067',
#   '118788',
#   '163732',
#   '80223',
#   '23031',
#   '56935',
#   '23135',
#   '11237',
#   '6256',
#   '3820',
#   '2635',
#   '728744',
#   '9806',
#   '389816',
#   '2947',
#   '283871',
#   '64174',
#   '112495',
#   '23396',
#   '359845',
#   '441168',
#   '27242',
#   '53635',
#   '83931',
#   '23492',
#   '162466',
#   '10403',
#   '9770',
#   '23097',
#   '57210',
#   '400652',
#   '4335',
#   '125950',
#   '55858',
#   '7805',
#   '8648',
#   '54820',
#   '654121',
#   '119504',
#   '90007',
#   '3613',
#   '91662',
#   '51010',
#   '64411',
#   '55262',
#   '3707',
#   '3428',
#   '5293',
#   '10797',
#   '56666',
#   '8408',
#   '5684',
#   '83719',
#   '60489',
#   '3251',
#   '5989',
#   '81788',
#   '58190',
#   '8019',
#   '391257',
#   '87',
#   '983',
#   '1729',
#   '10635',
#   '9739',
#   '6907',
#   '2643',
#   '84440',
#   '57666',
#   '26119',
#   '57153'],
#  'var_selectVnotComHC_grn3_cppls': [],
#  'var_selectVnotComHC_plsr': ['9638',
#   '220042',
#   '10643',
#   '8644',
#   '8660',
#   '3959',
#   '7128',
#   '2209',
#   '57595',
#   '5996',
#   '3418',
#   '3755',
#   '23523',
#   '7528',
#   '6890',
#   '4306',
#   '23067',
#   '118788',
#   '163732',
#   '80223',
#   '23031',
#   '56935',
#   '23135',
#   '11237',
#   '6256',
#   '3820',
#   '2635',
#   '728744',
#   '9806',
#   '389816',
#   '2947',
#   '283871',
#   '64174',
#   '112495',
#   '23396',
#   '359845',
#   '441168',
#   '27242',
#   '53635',
#   '83931',
#   '23492',
#   '162466',
#   '10403',
#   '9770',
#   '23097',
#   '57210',
#   '400652',
#   '4335',
#   '125950',
#   '55858',
#   '7805',
#   '8648',
#   '54820',
#   '654121',
#   '119504',
#   '90007',
#   '3613',
#   '91662',
#   '51010',
#   '64411',
#   '55262',
#   '3707',
#   '3428',
#   '5293',
#   '10797',
#   '56666',
#   '8408',
#   '5684',
#   '83719',
#   '60489',
#   '3251',
#   '5989',
#   '81788',
#   '58190',
#   '8019',
#   '391257',
#   '87',
#   '983',
#   '1729',
#   '10635',
#   '9739',
#   '6907',
#   '2643',
#   '84440',
#   '57666',
#   '26119',
#   '57153']}

# %%
print(len(overlapped_route_dict_list), count)
len(overlapped_all_dict)
# Out:
# 191 0
# 191

# %%
def get_score(_dict):
    _score_dict = {}
#     _dict = overlapped_all_dict
    for i in _dict.keys():
        for _gene in _dict[i]:
            if _gene not in _score_dict.keys():
                _score_dict[_gene] = 1
            else:
                _score_dict[_gene] += 1
    _list_key = list(_score_dict.keys())
    _temp_table = pd.DataFrame(data={'gene':_list_key, 'counts':[_score_dict[i] for i in _list_key]}, )
    _temp_table = _temp_table.sort_values('counts', ascending=False)
#     print(_temp_table.head())
    return _temp_table

# %%
all_score_table = get_score(overlapped_all_dict)
high_score_table = get_score(overlapped_high_dict)
mid_score_table = get_score(overlapped_mid_dict)
complete_score_table = get_score(overlapped_dict)
test_score_table = get_score(test_all_dict)

# %%
test_score_table_45 = test_score_table.head(45)
complete_score_table_45 = complete_score_table.head(45)
mid_score_table_45 = mid_score_table.head(45)
high_score_table_45 = high_score_table.head(45)
all_score_table_45 = all_score_table.head(45)
print(test_score_table.shape)
print(complete_score_table.shape)
print(mid_score_table.shape)
print(high_score_table.shape)
print(all_score_table.shape)
# Out:
# (3138, 2)
# (3112, 2)
# (2557, 2)
# (1921, 2)
# (1222, 2)

# %%
sns.boxplot(test_score_table.counts)
print(median)
plt.show()
sns.boxplot(complete_score_table.counts)
plt.show()
sns.boxplot(high_score_table.counts)
plt.show()
sns.boxplot(all_score_table.counts)
plt.show()

# %%
test_score_table.to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/complete_score_table_45.csv')
# Out:
#         gene  counts
# 127     9638     161
# 148   220042     116
# 523    10643     103
# 122     3613      97
# 89    115004      97
# ...      ...     ...
# 2764   55288       1
# 2756    4775       1
# 2753   92285       1
# 1232   27112       1
# 3137  653773       1
#
# [3138 rows x 2 columns]

# %%
complete_score_table_45.to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/complete_score_table_45.csv')
complete_score_table_45
# Out:
#        gene  counts
# 2      9638     161
# 1    220042     116
# 216   10643     103
# 133  115004      96
# 86   163732      92
# 19   359845      90
# 15     3613      90
# 88    57118      89
# 81     3755      87
# 39     5996      87
# 50   441168      85
# 80   219771      84
# 27     7704      83
# 57    55893      82
# 207   80790      81
# 70     1545      80
# 92    79699      80
# 52    57595      79
# 65    51099      78
# 30     8111      78
# 243   23492      78
# 78    80183      77
# 60    84166      76
# 44     5730      76
# 228   23067      76
# 16     4306      76
# 13     3820      76
# 111   55022      76
# 142    2788      75
# 102  114294      74
# 201    1380      74
# 215   10023      74
# 91     7174      74
# 85    94120      73
# 141   10219      73
# 0     10461      73
# 35     3985      73
# 31    54741      73
# 21     2999      73
# 3      8644      73
# 204  259197      72
# 9      7128      72
# 45     2947      72
# 128    2946      72
# 166    1455      71

# %%
mid_score_table_45.to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/mid_score_table_40.csv')
mid_score_table_45
# Out:
#        gene  counts
# 2      9638     149
# 1    220042     116
# 51   163732      90
# 16   359845      90
# 91    10643      86
# 32   441168      84
# 29     5996      82
# 53    57118      81
# 12     3613      81
# 34    57595      79
# 90     3755      77
# 13     4306      76
# 43     1545      74
# 3      8644      73
# 27     3985      72
# 104   23067      72
# 48    80183      71
# 242  219771      70
# 11     3820      70
# 44   283871      70
# 120   23492      70
# 71   115004      69
# 25    54741      69
# 7      7128      68
# 60    55022      68
# 39    84166      68
# 8      7572      68
# 22     7704      67
# 24     8111      67
# 56   114294      67
# 79     1455      66
# 50    94120      66
# 0     10461      66
# 49    57168      64
# 35   165631      64
# 85   114783      63
# 161    7174      62
# 243    9060      62
# 18     2999      62
# 410    5730      62
# 5      7850      61
# 73    10219      61
# 23   120103      61
# 72      311      60
# 86     1380      60

# %%
from venn import venn
# %matplotlib inline
gene_dict = {
    "complete_score_table": set(complete_score_table.head(100).gene),
    "mid_score_table": set(mid_score_table.head(100).gene),
    "high_score_table": set(high_score_table.head(100).gene),
    'all_score_table':set(all_score_table.head(100).gene)
}
venn(gene_dict)

# %%
complete_score_table_40[complete_score_table_40.gene.isin(complete_score_table_40.gene)].shape
# Out:
# (40, 2)

# %%
vahid_table = pd.read_excel('/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/data_supplementary/Progress_tracker.xlsx',sheet_name='Sheet2')
vahid_table.head()
# Out:
#        id  Score 220            Gene names  \
# 0    9638        136                  FEZ1
# 1  220042        114  DDIAS C11orf82 NOXIN
# 2   10461        111             MERTK MER
# 3   10788        111                IQGAP2
# 4    1545        111                CYP1B1
#
#                                        Protein names
# 0  Fasciculation and elongation protein zeta-1 (Z...
# 1  DNA damage-induced apoptosis suppressor protei...
# 2  Tyrosine-protein kinase Mer (EC 2.7.10.1) (Pro...
# 3          Ras GTPase-activating-like protein IQGAP2
# 4        Cytochrome P450 1B1 (EC 1.14.14.1) (CYPIB1)

# %%
print(test_score_table_45[test_score_table_45.gene.isin(vahid_table.id)].shape)
print(all_score_table_45[all_score_table_45.gene.isin(vahid_table.id)].shape)
print(high_score_table_45[high_score_table_45.gene.isin(vahid_table.id)].shape)
print(mid_score_table_45[mid_score_table_45.gene.isin(vahid_table.id)].shape)
print(complete_score_table_45[complete_score_table_45.gene.isin(vahid_table.id)].shape)
# Out:
# (26, 2)
# (12, 2)
# (22, 2)
# (24, 2)
# (28, 2)

# %%
xp_network = pd.read_csv('/Volumes/Work/r_note/asd_transcriptional_organization-master/rawData/networks/XP_networks/rawData/XP_func_anno.csv')
print(xp_network[xp_network['Entrez Gene ID'].isin(test_score_table.head(100).gene)].shape)
print(xp_network[xp_network['Entrez Gene ID'].isin(all_score_table.head(100).gene)].shape)
print(xp_network[xp_network['Entrez Gene ID'].isin(high_score_table.head(100).gene)].shape)
print(xp_network[xp_network['Entrez Gene ID'].isin(mid_score_table.head(100).gene)].shape)
print(xp_network[xp_network['Entrez Gene ID'].isin(complete_score_table.head(100).gene)].shape)
# Out:
# (48, 17)
# (73, 17)
# (66, 17)
# (53, 17)
# (50, 17)

# %%
name_prefix = 'complete_score_table_'
for i in [50,100,500,1000]:
    complete_score_table.head(i).to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/'+name_prefix+str(i)+'.csv')
name_prefix = 'all_score_table_'
for i in [50,100,500,1000]:
    all_score_table.head(i).to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/'+name_prefix+str(i)+'.csv')

# %%
np.median(complete_score_table.counts)
# Out:
# 10.0

# %%
name_prefix = 'all_score_table_'
all_score_table.to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/'+name_prefix+'all.csv')

# %%
name_prefix = 'complete_score_table_'

complete_score_table.to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/'+name_prefix+'all.csv')

# %%
xp_network[xp_network['Entrez Gene ID'].isin(mid_score_table_45.gene)][['annotation name','gene name','annotations']]
# Out:
#                                         annotation name gene name  \
# 4     negative regulation of sequence-specific DNA b...     NLRC5
# 110                                                 NaN     GPR68
# 123                  transcription coactivator activity    CITED4
# 140                                                 NaN      FEZ1
# 202                                                 NaN   IGF2BP3
# 242                                                 NaN     IL1R2
# 289            protein serine/threonine kinase activity   CSNK1G2
# 397   toll-like receptor 3 signaling pathway|extrins...   TNFAIP3
# 464                                                 NaN   SLC36A4
# 468                                                 NaN     SYTL3
# 505                                                 NaN    FAM26F
# 649                                                 NaN   FAM101B
# 681                                   dephosphorylation       PGP
# 697   protein methyltransferase activity|protein met...    SETD1B
# 704                                                 NaN     LACTB
# 763                         skeletal system development    PAPSS2
# 876   negative regulation of phosphorus metabolic pr...      PID1
# 902                   behavior|single-organism behavior     PTGDS
# 919   protein localization to nucleus|nuclear transp...    AKR1C3
# 974                     response to inorganic substance    ANXA11
# 1024  nuclear chromosome|nuclear chromatin|chromatin...      CBX7
# 1198                                                NaN     PDZD4
# 1359  skeletal system development|transcriptional re...    ZBTB16
# 1464  DNA-templated transcription, initiation|transc...     NR3C2
# 1572                                                NaN     KCNG1
# 1576  inositol phosphate phosphatase activity|dephos...     IMPA2
# 1723                                                NaN    MB21D1
# 1816                                  dephosphorylation     LMTK3
#
#                                             annotations
# 4                                            GO:0043433
# 110                                                 NaN
# 123                                          GO:0003713
# 140                                                 NaN
# 202                                                 NaN
# 242                                                 NaN
# 289                                          GO:0004674
# 397   GO:0034138|GO:0097191|GO:2001237|GO:0016879|GO...
# 464                                                 NaN
# 468                                                 NaN
# 505                                                 NaN
# 649                                                 NaN
# 681                                          GO:0016311
# 697   GO:0008276|GO:0006479|GO:0016570|GO:0008170|GO...
# 704                                                 NaN
# 763                                          GO:0001501
# 876   GO:0010563|GO:0008286|GO:0090005|GO:0015980|GO...
# 902                               GO:0007610|GO:0044708
# 919   GO:0034504|GO:0051169|GO:1902593|GO:0031668|GO...
# 974                                          GO:0010035
# 1024        GO:0000228|GO:0000790|GO:0000785|GO:0044454
# 1198                                                NaN
# 1359                              GO:0001501|GO:0017053
# 1464                   GO:0006352|GO:0006367|GO:0043235
# 1572                                                NaN
# 1576                              GO:0052745|GO:0016311
# 1723                                                NaN
# 1816                                         GO:0016311

# %%
def get_count(_table_dict, xp_network):
    a20 = xp_network[xp_network['Entrez Gene ID'].isin(_table_dict.head(20).gene)].shape[0]
    a50 = xp_network[xp_network['Entrez Gene ID'].isin(_table_dict.head(50).gene)].shape[0]
    a100 = xp_network[xp_network['Entrez Gene ID'].isin(_table_dict.head(100).gene)].shape[0]
    a500 = xp_network[xp_network['Entrez Gene ID'].isin(_table_dict.head(500).gene)].shape[0]
    return a20, a50, a100, a500

print(get_count(test_score_table, xp_network))
print(get_count(complete_score_table, xp_network))
print(get_count(mid_score_table, xp_network))
print(get_count(all_score_table, xp_network))
# Out:
# (12, 28, 48, 242)
# (12, 27, 50, 245)
# (12, 31, 53, 260)
# (14, 37, 73, 260)

# %%
import seaborn as sns
akk = pd.DataFrame(data={'classifier':[len(test_feature_method_dict[i]) for i in overlapped_route_dict_list], 
                         'gene_weight':feature_list})
sns.stripplot('classifier', 'gene_weight', data=akk, jitter=0.4, size=3)
sns.kdeplot(data=akk)
sns.despine()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
# Only pick the genes that exists in more than 60% of the features, pick gene that exist in 0.8 pick genes that exists in every set

# %% [markdown]
# # test the LD overlap with main

# %%
_the_table_ld = pd.read_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_testDataset_HT12_LD/roc_mean.csv', index_col=0)
_the_table_ld = _the_table_ld.drop('sqda', axis=1)
ld_feature_method_dict = {}               
route_list_ld = []
ld_feature_classifier = [[],[]]

for i in _the_table_ld.index.tolist():
    _name = "_".join(i.split("_")[1:])
    for j in _the_table_ld.columns.tolist():
        if _the_table_ld.loc[i,j] > 0.8:
            if _name not in ld_feature_method_dict.keys():
                ld_feature_method_dict[_name] = [j]
            else:
                ld_feature_method_dict[_name].append(j)
        ld_feature_classifier[0].append("@".join([_name,j]))
        ld_feature_classifier[1].append(_the_table_ld.loc[i,j])
route_list_ld = list(ld_feature_method_dict.keys())

with open('/Volumes/Work/Vahid_work/classification_newcode_data/final_testDataset_HT12_LD/feature.json') as f:
    data_ld = json.load(f)
ld_temp_dict = {}
for i in data_ld:
    name = "_".join(i['method'][0].split('_')[1:])
    if name not in ld_temp_dict.keys():
        ld_temp_dict[name]=[i['features']]
    else:
        ld_temp_dict[name].append(i['features'])

# %%
the_overlap_ld = sorted(list(set(main_feature_list).intersection(set(route_list_ld))))
len(the_overlap_ld)
# Out:
# 0

# %%
ld_feature_table = pd.DataFrame(data={"ld_feature": ld_feature_classifier[0], 'ld_roc':ld_feature_classifier[1]})
print(ld_feature_table.shape)
main_feature_table = pd.DataFrame(data={"main_feature": main_feature_classifier[0], 'main_roc':main_feature_classifier[1]})
print(main_feature_table.shape)
main_feature_table = main_feature_table[main_feature_table.main_feature.isin(ld_feature_table.ld_feature)]
main_feature_table = main_feature_table.sort_values(by="main_feature").reset_index(drop=True)
print(main_feature_table.shape)
ld_feature_table = ld_feature_table[ld_feature_table.ld_feature.isin(main_feature_table.main_feature)]
ld_feature_table = ld_feature_table.sort_values(by="ld_feature").reset_index(drop=True)
print(ld_feature_table.shape)
# Out:
# (19224, 2)
# (27612, 2)
# (19200, 2)
# (19200, 2)

# %% [markdown]
# # longitudinal

# %%
_the_table_long = pd.read_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_testDataset_HT12_longitudinal/roc_mean.csv', index_col=0)
_the_table_long = _the_table_long.drop('sqda', axis=1)
long_feature_method_dict = {}               
route_list_long = []
long_feature_classifier = [[],[]]

for i in _the_table_long.index.tolist():
    _name = "_".join(i.split("_")[1:])
    for j in _the_table_long.columns.tolist():
        if _the_table_long.loc[i,j] > 0.8:
            if _name not in long_feature_method_dict.keys():
                long_feature_method_dict[_name] = [j]
            else:
                long_feature_method_dict[_name].append(j)
        long_feature_classifier[0].append("@".join([_name,j]))
        long_feature_classifier[1].append(_the_table_long.loc[i,j])
route_list_long = list(long_feature_method_dict.keys())

with open('/Volumes/Work/Vahid_work/classification_newcode_data/final_testDataset_HT12_longitudinal/feature.json') as f:
    data_long = json.load(f)
long_temp_dict = {}
for i in data_long:
    name = "_".join(i['method'][0].split('_')[1:])
    if name not in long_temp_dict.keys():
        long_temp_dict[name]=[i['features']]
    else:
        long_temp_dict[name].append(i['features'])

# %%
the_overlap_long = sorted(list(set(main_feature_list).intersection(set(route_list_long))))
len(the_overlap_long)
# Out:
# 322

# %%
long_feature_table = pd.DataFrame(data={"long_feature": long_feature_classifier[0], 'long_roc':long_feature_classifier[1]})
print(long_feature_table.shape)
main_feature_table = pd.DataFrame(data={"main_feature": main_feature_classifier[0], 'main_roc':main_feature_classifier[1]})
print(main_feature_table.shape)
main_feature_table = main_feature_table[main_feature_table.main_feature.isin(long_feature_table.long_feature)]
main_feature_table = main_feature_table.sort_values(by="main_feature").reset_index(drop=True)
print(main_feature_table.shape)
long_feature_table = long_feature_table[long_feature_table.long_feature.isin(main_feature_table.main_feature)]
long_feature_table = long_feature_table.sort_values(by="long_feature").reset_index(drop=True)
print(long_feature_table.shape)
# Out:
# (20568, 2)
# (27612, 2)
# (20544, 2)
# (20544, 2)

# %%
merged_table = pd.concat([long_feature_table, main_feature_table], axis=1).dropna()
merged_table = merged_table[~(merged_table == 0).any(axis=1)]
import seaborn as sns
sns.scatterplot(data=merged_table, x="long_roc", y="main_roc", s=10)
sns.kdeplot(data=merged_table[["long_roc", "main_roc"]])

# %%
temp_LW_report = pd.read_csv('/Volumes/Work/Autism/data_910/LWReport_04182020_updated.csv', header=0)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (455) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
temp_LW_report.recentDxJ_ageMo
# Out:
# 0       35.000
# 1       35.000
# 2       36.000
# 3       41.166
# 4       31.343
#          ...
# 2971    33.000
# 2972    38.000
# 2973    33.117
# 2974    34.530
# 2975    58.448
# Name: recentDxJ_ageMo, Length: 2976, dtype: float64

# %%
temp_LW_report.recentDxJ_dxCode.value_counts()
# Out:
# ASD              1182
# TD                601
# LD                346
# Other             202
# DD                171
# ASD Features      131
# Typ Sib ASD        80
# PrevLDDTyp         76
# GDD                50
# PDDNOS             49
# FMD                24
# PrevDDTyp          12
# DROPPED             9
# MD                  9
# ADHD                8
# PrevASDTyp          3
# Dropped             2
# Aspergers           1
# ASD Features        1
# Name: recentDxJ_dxCode, dtype: int64

# %%
recentDxJ_dxCode_dict = {'ASD':'ASD',
'TD':'TD',
'LD':'LD',
'Other':'Other',
'DD':'GDD',
'ASD Features':'ASD Features',
'ASD Features ':'ASD Features',
'Typ Sib ASD':'TypSibASD',
'PrevLDDTyp':'TD',
'GDD':'GDD',
'PDDNOS':'ASD',
'FMD':'Other',
'PrevDDTyp':'TD',
'MD':'Other',
'DROPPED':'Dropped',
'ADHD':'Other',
'PrevASDTyp':'ASD',
'Dropped':'Dropped',
'ASD Features':'Other',
'Aspergers':'Other'}

subject_dx_dict = {}
for i,j in zip(temp_LW_report.subjectid.tolist(), temp_LW_report.recentDxJ_dxCode.tolist()):
    if type(j) is str:
        subject_dx_dict[i] = recentDxJ_dxCode_dict[j]

# %%
ados_table = temp_LW_report[['subjectid','ados_CoSoTot_1','ados_CoSoTot_2','ados_CoSoTot_3', 'ados_CoSoTot_4','ados_CoSoTot_5']]
ados_table.head()

mullen_table = temp_LW_report[['subjectid','mullen_ELC_Std_1','mullen_ELC_Std_2','mullen_ELC_Std_3', 'mullen_ELC_Std_4','mullen_ELC_Std_5']]
mullen_table.head()

mullen_table_1 = temp_LW_report[['subjectid','mullen_ELC_Std_1','mullen_ELC_Std_2','mullen_ELC_Std_3', 'mullen_ELC_Std_4','mullen_ELC_Std_5']]
mullen_table.head()

CSBS_sub1_social_2
CSBS_sub2_expressive_2
CSBS_sub3_symbolic_2
CSBS_total_score_2
mullen_ELT_1
ados_RRTot_1
ados_CoSoTotRRTot_1
# Out:
#   subjectid  mullen_ELC_Std_1  mullen_ELC_Std_2  mullen_ELC_Std_3  \
# 0     A2A4U             101.0             102.0               NaN
# 1     A2C6R              56.0              56.0               NaN
# 2     A2C9K             117.0             111.0             127.0
# 3     A2F7W              72.0               NaN               NaN
# 4     A2G9A              85.0              89.0               NaN
#
#    mullen_ELC_Std_4  mullen_ELC_Std_5
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN

# %%
subject_ados_score = {}
for i in ados_table.index.tolist():
    for j in ['ados_CoSoTot_5','ados_CoSoTot_4','ados_CoSoTot_3','ados_CoSoTot_2','ados_CoSoTot_1']:
        if np.isnan(ados_table.loc[i,j]):
            continue
        else:
#             subject_id_list.append(cutted_table.subjectid[i])
#             thelast_asd_list.append(cutted_table.loc[i,j])
            subject_ados_score[ados_table.subjectid[i]] = ados_table.loc[i,j]
            break
subject_mullen_score = {}
for i in mullen_table.index.tolist():
    for j in ['mullen_ELC_Std_5','mullen_ELC_Std_4','mullen_ELC_Std_3','mullen_ELC_Std_2','mullen_ELC_Std_1']:
        if np.isnan(mullen_table.loc[i,j]):
            continue
        else:
#             subject_id_list.append(cutted_table.subjectid[i])
#             thelast_asd_list.append(cutted_table.loc[i,j])
            subject_mullen_score[mullen_table.subjectid[i]] = mullen_table.loc[i,j]
            break
        
for i in mullen_table.index.tolist():
    for j in ['mullen_ELC_Std_5','mullen_ELC_Std_4','mullen_ELC_Std_3','mullen_ELC_Std_2','mullen_ELC_Std_1']:
        if np.isnan(mullen_table.loc[i,j]):
            continue
        else:
#             subject_id_list.append(cutted_table.subjectid[i])
#             thelast_asd_list.append(cutted_table.loc[i,j])
            subject_mullen_score[mullen_table.subjectid[i]] = mullen_table.loc[i,j]
            break
        
age_dict={}
for i in temp_LW_report.index.tolist():
    age_dict[temp_LW_report.subjectid[i]] = temp_LW_report.recentDxJ_ageMo[i]

# %%
main_subject = pd.read_csv("/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/main_pheno.csv",index_col=0)
test_subject = pd.read_csv("/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/test_pheno.csv",index_col=0)

# %%
main_subject.head()
# Out:
#              subjectId blooddrawid     age recentDx_EvalDate diagnosis_binary  \
# 4807135042_B     A2H7X      239-01  22.899      11/7/08 0:00              ASD
# 223              A2Y4H      576-01  35.483          04-26-10              ASD
# 363              A9P5P      837-01  16.066          12-11-13               TD
# 135              B2J9W      429-01  17.281          02-17-11              ASD
# 168              B4C2A      478-01  12.945          06-20-11               TD
#
#              diagnosis_multi1 batch sex  Neutrophil     Tcell  Monocyte  \
# 4807135042_B           PDDNOS   WG6   M   -0.036209  0.034645 -0.031791
# 223                    PDDNOS     1   M    0.007828 -0.004516  0.018506
# 363                        TD     1   M   -0.044216  0.054873 -0.070569
# 135                       ASD     1   M   -0.049209  0.050637  0.005405
# 168                PrevLDDTyp     1   M    0.026765  0.005010 -0.010309
#
#                  Bcell    NKcell  PlasmaCell  DendriticCell
# 4807135042_B  0.014288  0.031658   -0.001823      -0.024369
# 223           0.026279 -0.020799   -0.049248      -0.034710
# 363           0.043028 -0.003206    0.033454      -0.006598
# 135           0.023745  0.037971    0.012080      -0.039781
# 168           0.045445 -0.018475    0.000262      -0.011606

# %%
main_ados = []
for i in main_subject.subjectId.tolist():
    main_ados.append(subject_ados_score[i])
    
test_ados = []
for i in test_subject.subjectId.tolist():
    test_ados.append(subject_ados_score[i])

main_dx = []
for i in main_subject.subjectId.tolist():
    main_dx.append(subject_dx_dict[i])
    
test_dx = []
for i in test_subject.subjectId.tolist():
    test_dx.append(subject_dx_dict[i])
    
main_age = []
for i in main_subject.subjectId.tolist():
    main_age.append(age_dict[i])
    
test_age = []
for i in test_subject.subjectId.tolist():
    test_age.append(age_dict[i])

# %%
main_subject['final_ADOS_CoSoTot'] = main_ados
test_subject['final_ADOS_CoSoTot'] = test_ados
main_subject['recentDxJ_dxCode'] = main_dx
test_subject['recentDxJ_dxCode'] = test_dx
main_subject['recentDxJ_ageMo'] = main_age
test_subject['recentDxJ_ageMo'] = test_age
test_subject.to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/test_pheno_up.csv')
main_subject.to_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/main_pheno_up.csv')

# %%
aaa = pd.read_csv('/Volumes/Work/Vahid_work/classification_newcode_data/final_result_plot/gene_info.csv', sep='\t', index_col=0)

# %%
# Out:
#                   ID       Species  Source   Search_Key  Transcript ILMN_Gene  \
# 220042  ILMN_1790100  Homo sapiens  RefSeq  NM_145018.2  ILMN_11038  C11ORF82
#
#        Source_Reference_ID    RefSeq_ID  Unigene_ID  Entrez_Gene_ID  ...  \
# 220042         NM_145018.2  NM_145018.2         NaN          220042  ...
#
#         Probe_Coordinates  Cytoband  \
# 220042  82322969-82323018  11q14.1d
#
#                                                Definition Ontology_Component  \
# 220042  \Homo sapiens chromosome 11 open reading frame...                NaN
#
#        Ontology_Process  Ontology_Function                      Synonyms  \
# 220042              NaN                NaN  FLJ38838; FLJ13936; FLJ25416
#
#                    Obsolete_Probe_Id       GB_ACC geneSymbol
# 220042  FLJ38838; FLJ25416; FLJ13936  NM_145018.2      DDIAS
#
# [1 rows x 31 columns]

# %%
'comp1' in aaa.index.tolist()
# Out:
# False

# %%
sorted(aaa.index.tolist())
# Out:
# [1,
#  9,
#  14,
#  16,
#  18,
#  19,
#  20,
#  22,
#  23,
#  24,
#  25,
#  26,
#  29,
#  30,
#  31,
#  32,
#  34,
#  35,
#  36,
#  37,
#  38,
#  39,
#  40,
#  41,
#  43,
#  47,
#  48,
#  50,
#  51,
#  52,
#  53,
#  54,
#  55,
#  59,
#  60,
#  71,
#  81,
#  86,
#  87,
#  88,
#  90,
#  91,
#  92,
#  95,
#  97,
#  98,
#  100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  108,
#  109,
#  113,
#  115,
#  118,
#  120,
#  123,
#  124,
#  128,
#  132,
#  133,
#  134,
#  135,
#  136,
#  140,
#  141,
#  142,
#  143,
#  146,
#  150,
#  151,
#  152,
#  154,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  172,
#  175,
#  177,
#  178,
#  181,
#  182,
#  191,
#  196,
#  199,
#  202,
#  203,
#  204,
#  205,
#  207,
#  208,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  219,
#  221,
#  223,
#  224,
#  226,
#  229,
#  230,
#  231,
#  239,
#  240,
#  241,
#  244,
#  245,
#  246,
#  247,
#  249,
#  250,
#  251,
#  257,
#  262,
#  267,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  283,
#  284,
#  286,
#  288,
#  290,
#  291,
#  292,
#  301,
#  302,
#  303,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  313,
#  314,
#  317,
#  318,
#  321,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  334,
#  335,
#  351,
#  353,
#  355,
#  356,
#  357,
#  358,
#  360,
#  363,
#  366,
#  368,
#  369,
#  372,
#  373,
#  375,
#  377,
#  378,
#  381,
#  383,
#  384,
#  387,
#  388,
#  389,
#  391,
#  392,
#  393,
#  396,
#  397,
#  398,
#  400,
#  402,
#  403,
#  405,
#  406,
#  408,
#  409,
#  410,
#  411,
#  414,
#  420,
#  427,
#  430,
#  432,
#  433,
#  434,
#  435,
#  440,
#  444,
#  463,
#  466,
#  467,
#  468,
#  471,
#  472,
#  473,
#  475,
#  476,
#  480,
#  481,
#  482,
#  483,
#  486,
#  488,
#  489,
#  490,
#  493,
#  498,
#  501,
#  506,
#  509,
#  513,
#  515,
#  516,
#  517,
#  518,
#  521,
#  522,
#  523,
#  526,
#  527,
#  528,
#  529,
#  533,
#  534,
#  535,
#  537,
#  538,
#  539,
#  545,
#  546,
#  549,
#  550,
#  551,
#  558,
#  566,
#  567,
#  571,
#  572,
#  573,
#  578,
#  580,
#  581,
#  582,
#  583,
#  585,
#  586,
#  587,
#  593,
#  594,
#  595,
#  596,
#  597,
#  598,
#  599,
#  602,
#  604,
#  605,
#  607,
#  608,
#  611,
#  613,
#  617,
#  618,
#  622,
#  623,
#  627,
#  629,
#  632,
#  634,
#  637,
#  638,
#  639,
#  640,
#  641,
#  642,
#  643,
#  644,
#  645,
#  646,
#  648,
#  649,
#  650,
#  654,
#  656,
#  657,
#  659,
#  660,
#  661,
#  662,
#  663,
#  664,
#  665,
#  666,
#  669,
#  670,
#  671,
#  672,
#  673,
#  677,
#  678,
#  682,
#  683,
#  684,
#  686,
#  687,
#  689,
#  694,
#  695,
#  699,
#  701,
#  705,
#  706,
#  708,
#  710,
#  712,
#  713,
#  714,
#  715,
#  717,
#  719,
#  722,
#  726,
#  727,
#  728,
#  733,
#  734,
#  738,
#  740,
#  741,
#  746,
#  747,
#  752,
#  753,
#  754,
#  755,
#  757,
#  758,
#  759,
#  760,
#  762,
#  763,
#  765,
#  767,
#  770,
#  773,
#  774,
#  775,
#  777,
#  780,
#  784,
#  785,
#  788,
#  790,
#  794,
#  800,
#  801,
#  805,
#  808,
#  811,
#  813,
#  814,
#  816,
#  817,
#  818,
#  819,
#  820,
#  821,
#  822,
#  823,
#  824,
#  825,
#  826,
#  828,
#  829,
#  830,
#  831,
#  832,
#  833,
#  834,
#  835,
#  836,
#  837,
#  838,
#  839,
#  840,
#  841,
#  842,
#  843,
#  847,
#  857,
#  858,
#  860,
#  861,
#  863,
#  864,
#  865,
#  867,
#  868,
#  871,
#  873,
#  874,
#  875,
#  883,
#  886,
#  889,
#  890,
#  891,
#  892,
#  894,
#  896,
#  898,
#  899,
#  900,
#  901,
#  902,
#  904,
#  905,
#  908,
#  909,
#  910,
#  911,
#  912,
#  913,
#  914,
#  915,
#  916,
#  917,
#  919,
#  920,
#  921,
#  923,
#  924,
#  925,
#  926,
#  928,
#  929,
#  930,
#  931,
#  932,
#  933,
#  939,
#  940,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  948,
#  949,
#  950,
#  951,
#  952,
#  953,
#  955,
#  956,
#  958,
#  959,
#  960,
#  961,
#  962,
#  963,
#  965,
#  966,
#  967,
#  968,
#  969,
#  970,
#  971,
#  972,
#  973,
#  974,
#  975,
#  976,
#  977,
#  978,
#  983,
#  984,
#  985,
#  987,
#  988,
#  989,
#  991,
#  993,
#  994,
#  995,
#  997,
#  998,
#  999,
#  1000,
#  1009,
#  1017,
#  1018,
#  1019,
#  1020,
#  1021,
#  1022,
#  1024,
#  1025,
#  1026,
#  1027,
#  1028,
#  1030,
#  1031,
#  1032,
#  1033,
#  1039,
#  1043,
#  1050,
#  1051,
#  1052,
#  1053,
#  1054,
#  1056,
#  1058,
#  1059,
#  1060,
#  1062,
#  1063,
#  1066,
#  1068,
#  1069,
#  1070,
#  1071,
#  1072,
#  1075,
#  1084,
#  1088,
#  1089,
#  1101,
#  1102,
#  1103,
#  1104,
#  1105,
#  1106,
#  1107,
#  1108,
#  1109,
#  1111,
#  1112,
#  1117,
#  1119,
#  1120,
#  1121,
#  1122,
#  1123,
#  1124,
#  1130,
#  1135,
#  1136,
#  1138,
#  1140,
#  1147,
#  1152,
#  1153,
#  1154,
#  1155,
#  1161,
#  1163,
#  1164,
#  1173,
#  1174,
#  1175,
#  1176,
#  1178,
#  1182,
#  1183,
#  1185,
#  1186,
#  1192,
#  1193,
#  1195,
#  1196,
#  1197,
#  1198,
#  1200,
#  1201,
#  1203,
#  1207,
#  1209,
#  1211,
#  1212,
#  1213,
#  1230,
#  1231,
#  1232,
#  1233,
#  1234,
#  1235,
#  1236,
#  1240,
#  1241,
#  1244,
#  1258,
#  1263,
#  1265,
#  1266,
#  1269,
#  1285,
#  1290,
#  1292,
#  1293,
#  1294,
#  1296,
#  1298,
#  1303,
#  1308,
#  1312,
#  1314,
#  1315,
#  1316,
#  1317,
#  1318,
#  1326,
#  1327,
#  1329,
#  1337,
#  1340,
#  1345,
#  1347,
#  1349,
#  1350,
#  1351,
#  1352,
#  1353,
#  1355,
#  1359,
#  1360,
#  1361,
#  1362,
#  1366,
#  1368,
#  1370,
#  1374,
#  1375,
#  1376,
#  1378,
#  1380,
#  1382,
#  1384,
#  1385,
#  1386,
#  1387,
#  1388,
#  1389,
#  1392,
#  1394,
#  1396,
#  1397,
#  1398,
#  1399,
#  1400,
#  1407,
#  1408,
#  1415,
#  1418,
#  1419,
#  1427,
#  1428,
#  1429,
#  1431,
#  1432,
#  1434,
#  1436,
#  1438,
#  1439,
#  1441,
#  1444,
#  1445,
#  1452,
#  1453,
#  1454,
#  1455,
#  1456,
#  1457,
#  1459,
#  1460,
#  1462,
#  1463,
#  1465,
#  1468,
#  1471,
#  1475,
#  1476,
#  1477,
#  1478,
#  1479,
#  1486,
#  1487,
#  1488,
#  1490,
#  1491,
#  1493,
#  1495,
#  1497,
#  1499,
#  1500,
#  1503,
#  1506,
#  1508,
#  1509,
#  1510,
#  1511,
#  1512,
#  1513,
#  1514,
#  1519,
#  1520,
#  1521,
#  1522,
#  1523,
#  1524,
#  1528,
#  1534,
#  1535,
#  1536,
#  1537,
#  1539,
#  1540,
#  1545,
#  1549,
#  1557,
#  1564,
#  1573,
#  1583,
#  1592,
#  1593,
#  1595,
#  1601,
#  1602,
#  1603,
#  1604,
#  1605,
#  1606,
#  1608,
#  1609,
#  1611,
#  1612,
#  1613,
#  1615,
#  1616,
#  1622,
#  1627,
#  1628,
#  1629,
#  1632,
#  1633,
#  1634,
#  1635,
#  1639,
#  1641,
#  1642,
#  1643,
#  1646,
#  1647,
#  1649,
#  1650,
#  1652,
#  1653,
#  1654,
#  1655,
#  1656,
#  1657,
#  1659,
#  1660,
#  1662,
#  1663,
#  1665,
#  1666,
#  1667,
#  1668,
#  1669,
#  1672,
#  1675,
#  1676,
#  1677,
#  1678,
#  1687,
#  1690,
#  1716,
#  1717,
#  1718,
#  1719,
#  1723,
#  1725,
#  1727,
#  1728,
#  1729,
#  1730,
#  1731,
#  1736,
#  1737,
#  1738,
#  1741,
#  1742,
#  1743,
#  1748,
#  1755,
#  1756,
#  1760,
#  1762,
#  1763,
#  1767,
#  1773,
#  1774,
#  1776,
#  1777,
#  1778,
#  1781,
#  1783,
#  1785,
#  1786,
#  1787,
#  1788,
#  1789,
#  1791,
#  1794,
#  1796,
#  1797,
#  1798,
#  1801,
#  1802,
#  1803,
#  1806,
#  1807,
#  1808,
#  1809,
#  1810,
#  1814,
#  1815,
#  1819,
#  1820,
#  1822,
#  1823,
#  1824,
#  1826,
#  1827,
#  1831,
#  1832,
#  1836,
#  1838,
#  1839,
#  1840,
#  1843,
#  1844,
#  1845,
#  1846,
#  1847,
#  1848,
#  1849,
#  1850,
#  1854,
#  1855,
#  1856,
#  1857,
#  1859,
#  1861,
#  1870,
#  1871,
#  1874,
#  1875,
#  1876,
#  1877,
#  1879,
#  1880,
#  1889,
#  1890,
#  1891,
#  1892,
#  1894,
#  1901,
#  1902,
#  1903,
#  1906,
#  1910,
#  1911,
#  1912,
#  1915,
#  1917,
#  1933,
#  1936,
#  1937,
#  1938,
#  1939,
#  1942,
#  1945,
#  1947,
#  1948,
#  1950,
#  1951,
#  1952,
#  1955,
#  1958,
#  1959,
#  1960,
#  1962,
#  1964,
#  1965,
#  1967,
#  1968,
#  1973,
#  1974,
#  1975,
#  1977,
#  1978,
#  1979,
#  1981,
#  1982,
#  1983,
#  1984,
#  1990,
#  1991,
#  1992,
#  1994,
#  1995,
#  1997,
#  1998,
#  2000,
#  2002,
#  2005,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2017,
#  2020,
#  2021,
#  2022,
#  2023,
#  2026,
#  2027,
#  2029,
#  2030,
#  2033,
#  2034,
#  2035,
#  2037,
#  2038,
#  2039,
#  2040,
#  2041,
#  2043,
#  2046,
#  2047,
#  2048,
#  2050,
#  2051,
#  2052,
#  2053,
#  2054,
#  2055,
#  2057,
#  2058,
#  2059,
#  2060,
#  2063,
#  2064,
#  2066,
#  2067,
#  2068,
#  2071,
#  2072,
#  2073,
#  2074,
#  2077,
#  2078,
#  2079,
#  2081,
#  2086,
#  ...]

# %%
# test_subject.final_ADOS_CoSoTot.tolist()

aaaa = [9638,220042,10461,10788,1545,115004,3613,3755,311,10023,163732,2947,441168,54741,55022,57118,57595,5996,80790,84166,8644,10219,7704,112770,1675,26519,2946,359845,54541,5730,8857,140803,2999,10598,2275,3458,2026,55893,200014,25849,3985,8904,9619,8111]

# %%
xp_network = pd.read_csv('/Volumes/Work/r_note/asd_transcriptional_organization-master/rawData/networks/XP_networks/rawData/XP_func_anno.csv')

# %%
xp_network['Entrez Gene ID']
# Out:
# 0          129684
# 1           25832
# 2            5625
# 3           56666
# 4           84166
#           ...
# 1860       440563
# 1861       649330
# 1862          277
# 1863    100191040
# 1864       729020
# Name: Entrez Gene ID, Length: 1865, dtype: int64

# %% [markdown]
# # Prenatal events
